# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install feature_engine
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feature_engine
#   Downloading feature_engine-1.5.2-py2.py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (1.7.3)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (0.12.2)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (1.3.5)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (1.0.2)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.3->feature_engine) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.3->feature_engine) (2022.7)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.0->feature_engine) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.0->feature_engine) (3.1.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.11.1->feature_engine) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5->statsmodels>=0.11.1->feature_engine) (1.15.0)
# Installing collected packages: feature_engine
# Successfully installed feature_engine-1.5.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0

# %%
import numpy as np
import pandas as pd
import os
import sys

import joblib # saving sklearn modules
from sklearn.impute import KNNImputer # completing missing values using k-Nearest Neighbors
from feature_engine.encoding import WoEEncoder # encode only categorical variables (type ‘object’)
from sklearn.linear_model import LogisticRegression, HuberRegressor

from tensorflow.keras import Sequential  
from tensorflow.keras.layers import BatchNormalization, Dropout, Dense
import tensorflow as tf
from tensorflow_addons.optimizers import AdamW
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
Train = pd.read_csv('/content/drive/MyDrive/大三上作業/ML_final/train.csv')
Test = pd.read_csv('/content/drive/MyDrive/大三上作業/ML_final/test.csv')

# %%
data = pd.concat([Train, Test])
# create lists that will be used
codes = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
drops = ['id', 'product_code', 'loading', 'attribute_0', 'attribute_1', 'attribute_2', 'attribute_3', 'loading', 'missing3', 'missing5']
featureM = [f for f in data.columns if f.startswith('measurement') or f=='loading']
features = ['loading', 'attribute_0', 'measurement_17', 'measurement_0','measurement_1', 'measurement_2', 'attr23', 'missing3', 'missing5']

# create a dict for measurements 3-17 because they contain value lost (*reference)
measurements = {}
# set up measurement 17 manually
measurements['measurement_17'] = {
        'A': ['measurement_5','measurement_6','measurement_8','measurement_7'],
        'B': ['measurement_4','measurement_5','measurement_7','measurement_9'],
        'C': ['measurement_5','measurement_7','measurement_8','measurement_9'],
        'D': ['measurement_5','measurement_6','measurement_7','measurement_8'],
        'E': ['measurement_4','measurement_5','measurement_6','measurement_8'],
        'F': ['measurement_4','measurement_5','measurement_6','measurement_7'],
        'G': ['measurement_4','measurement_6','measurement_8','measurement_9'],
        'H': ['measurement_4','measurement_5','measurement_7','measurement_8','measurement_9'],
        'I': ['measurement_3','measurement_7','measurement_8','measurement_9']
    }

# when measurement_3 is missing, the failure rate is 0.160 (much lower than average)    
data['missing3'] = data['measurement_3'].isna().astype(np.int8)
# when measurement_5 is missing, the failure rate is 0.254 (much higher than average)
data['missing5'] = data['measurement_5'].isna().astype(np.int8)
# attribute_2 has two values (5 and 8) which occur only in the training data, and another value (7) occurs only in the test data, attribute_3 is similar.
data['attr23'] = data['attribute_2'] * data['attribute_3']

# get the correlation values of measurements 3-16
colName = []
value = []
for i in range(3,17):
    colName.append(f'measurement_{i}')
    corr = np.absolute(data.drop(drops, axis=1).corr()[f'measurement_{i}']).sort_values(ascending=False)
    value.append(np.sum(corr[1:4]))

# take the measurements in order of sorted correlation
measurementCorr = pd.DataFrame({'column name': colName, 'values': value})
sortedMeasurement = measurementCorr.sort_values(by='values', ascending=False).reset_index(drop=True)
for i in range(10): # only take the top 10
    whichMeasurement = sortedMeasurement.iloc[i, 0]
    best4 = {} # pick 4 measurements with best correlations for each product_code
    for c in codes: 
        corr = np.absolute(data[data.product_code == c].drop(drops, axis=1).corr()[whichMeasurement]).sort_values(ascending=False)
        best4[c] = corr[1:5].index.tolist()
    measurements[whichMeasurement] = best4 # measurement_i | product_code : measurement_i1, measurement_i2, measurement_i3, measurement_i4

# for each product_code
for code in codes:
    # fill the measurement columns with linear model
    for measure in list(measurements.keys()):
        dataM = data[data.product_code == code]
        best4 = measurements[measure][code] # product_code : measurement_i1, measurement_i2, measurement_i3, measurement_i4
        trainM = dataM[best4+[measure]].dropna(how='any') # 4 related + itself as target (all should not be null)
        testM = dataM[(dataM[best4].isnull().sum(axis=1)==0) & (dataM[measure].isnull())] # 4 related (no null) + itself as target (null)
        modelLinear = HuberRegressor(epsilon=1.75)
        modelLinear.fit(trainM[best4], trainM[measure])
        data.loc[(data.product_code==code)&(data[best4].isnull().sum(axis=1)==0)&(data[measure].isnull()), measure] = modelLinear.predict(testM[best4])
    # fill the others N/A columns with KNN (k=3)
    modelKnn = KNNImputer(n_neighbors=3)
    data.loc[data.product_code==code, featureM] = modelKnn.fit_transform(data.loc[data.product_code==code, featureM])

# encode attribute_0
train = data.iloc[:len(Train.index)]
encode = WoEEncoder(variables=['attribute_0'])
encode.fit(train, train['failure'])
train = encode.transform(train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
# first 3 codes for training, latter 2 for validation (*reference)
folds = {'fold_1': [['C', 'D', 'E'], ['A', 'B']], 
         'fold_2': [['B', 'D', 'E'], ['A', 'C']],
         'fold_3': [['B', 'C', 'E'], ['A', 'D']],
         'fold_4': [['B', 'C', 'D'], ['A', 'E']],
         'fold_5': [['A', 'D', 'E'], ['B', 'C']],
         'fold_6': [['A', 'C', 'E'], ['B', 'D']],
         'fold_7': [['A', 'C', 'D'], ['B', 'E']],
         'fold_8': [['A', 'B', 'E'], ['C', 'D']],
         'fold_9': [['A', 'B', 'D'], ['C', 'E']],
         'fold_10': [['A', 'B', 'C'], ['D', 'E']]}

tf.random.set_seed(85)
# set up the callbacks
bestModel = ModelCheckpoint('best.h5', verbose=1, save_best_only=True, monitor="auc", mode="max")
earlyStop = EarlyStopping(patience=10, restore_best_weights=True)
reduceLr = ReduceLROnPlateau(monitor="auc", factor=0.9, patience=5, mode="max", min_delta=0.0001)

# run through all the folds
for fold in folds.keys():
    print(f'\n{fold}\n')
    
    x_train, y_train = train[train['product_code'].isin(folds[fold][0])][features].values, train[train['product_code'].isin(folds[fold][0])]['failure'].values
    x_valid, y_valid = train[train['product_code'].isin(folds[fold][1])][features].values, train[train['product_code'].isin(folds[fold][1])]['failure'].values

    # create a new model for each fold
    model = Sequential()
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(len(x_train), activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(128, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(64, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(32, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(1, activation="sigmoid"))

    model.compile(optimizer=AdamW(learning_rate=1e-3, weight_decay=1e-3), loss=BinaryCrossentropy(), metrics=["AUC"])
    model.fit(x_train, y_train, batch_size = 64, epochs = 100, callbacks=[earlyStop, reduceLr, bestModel], validation_data=(x_valid, y_valid))
# Out:
# fold_1
#
# Epoch 1/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.6093 - auc: 0.5273
# Epoch 1: auc improved from -inf to 0.52775, saving model to best.h5
# 254/254 [==============================] - 8s 12ms/step - loss: 0.6080 - auc: 0.5277 - val_loss: 0.5245 - val_auc: 0.5417 - lr: 0.0010
# Epoch 2/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5260 - auc: 0.5461
# Epoch 2: auc improved from 0.52775 to 0.54657, saving model to best.h5
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5264 - auc: 0.5466 - val_loss: 0.5181 - val_auc: 0.5441 - lr: 0.0010
# Epoch 3/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5187 - auc: 0.5471
# Epoch 3: auc improved from 0.54657 to 0.54715, saving model to best.h5
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5187 - auc: 0.5471 - val_loss: 0.5156 - val_auc: 0.5778 - lr: 0.0010
# Epoch 4/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5152 - auc: 0.5580
# Epoch 4: auc improved from 0.54715 to 0.55804, saving model to best.h5
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5152 - auc: 0.5580 - val_loss: 0.5129 - val_auc: 0.5895 - lr: 0.0010
# Epoch 5/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5138 - auc: 0.5663
# Epoch 5: auc improved from 0.55804 to 0.56705, saving model to best.h5
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5131 - auc: 0.5670 - val_loss: 0.5139 - val_auc: 0.5783 - lr: 0.0010
# Epoch 6/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5114 - auc: 0.5686
# Epoch 6: auc improved from 0.56705 to 0.56904, saving model to best.h5
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5117 - auc: 0.5690 - val_loss: 0.5114 - val_auc: 0.5926 - lr: 0.0010
# Epoch 7/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5119 - auc: 0.5759
# Epoch 7: auc improved from 0.56904 to 0.57626, saving model to best.h5
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5112 - auc: 0.5763 - val_loss: 0.5133 - val_auc: 0.5853 - lr: 0.0010
# Epoch 8/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5120 - auc: 0.5649
# Epoch 8: auc did not improve from 0.57626
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5121 - auc: 0.5647 - val_loss: 0.5139 - val_auc: 0.5945 - lr: 0.0010
# Epoch 9/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5104 - auc: 0.5763
# Epoch 9: auc improved from 0.57626 to 0.57653, saving model to best.h5
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5108 - auc: 0.5765 - val_loss: 0.5119 - val_auc: 0.5950 - lr: 0.0010
# Epoch 10/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5120 - auc: 0.5731
# Epoch 10: auc did not improve from 0.57653
# 254/254 [==============================] - 2s 9ms/step - loss: 0.5119 - auc: 0.5715 - val_loss: 0.5119 - val_auc: 0.5928 - lr: 0.0010
# Epoch 11/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5112 - auc: 0.5744
# Epoch 11: auc did not improve from 0.57653
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5110 - auc: 0.5752 - val_loss: 0.5107 - val_auc: 0.5933 - lr: 0.0010
# Epoch 12/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5121 - auc: 0.5648
# Epoch 12: auc did not improve from 0.57653
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5121 - auc: 0.5648 - val_loss: 0.5163 - val_auc: 0.5924 - lr: 0.0010
# Epoch 13/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5118 - auc: 0.5704
# Epoch 13: auc did not improve from 0.57653
# 254/254 [==============================] - 2s 9ms/step - loss: 0.5116 - auc: 0.5714 - val_loss: 0.5262 - val_auc: 0.5893 - lr: 0.0010
# Epoch 14/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5117 - auc: 0.5698
# Epoch 14: auc did not improve from 0.57653
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5118 - auc: 0.5695 - val_loss: 0.5161 - val_auc: 0.5921 - lr: 0.0010
# Epoch 15/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5108 - auc: 0.5770
# Epoch 15: auc improved from 0.57653 to 0.57696, saving model to best.h5
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5108 - auc: 0.5770 - val_loss: 0.5118 - val_auc: 0.5921 - lr: 9.0000e-04
# Epoch 16/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5124 - auc: 0.5647
# Epoch 16: auc did not improve from 0.57696
# 254/254 [==============================] - 4s 17ms/step - loss: 0.5127 - auc: 0.5639 - val_loss: 0.5115 - val_auc: 0.5929 - lr: 9.0000e-04
# Epoch 17/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5117 - auc: 0.5706
# Epoch 17: auc did not improve from 0.57696
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5115 - auc: 0.5711 - val_loss: 0.5139 - val_auc: 0.5925 - lr: 9.0000e-04
# Epoch 18/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5119 - auc: 0.5673
# Epoch 18: auc did not improve from 0.57696
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5119 - auc: 0.5679 - val_loss: 0.5117 - val_auc: 0.5900 - lr: 9.0000e-04
# Epoch 19/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5114 - auc: 0.5698
# Epoch 19: auc did not improve from 0.57696
# 254/254 [==============================] - 2s 9ms/step - loss: 0.5119 - auc: 0.5694 - val_loss: 0.5118 - val_auc: 0.5932 - lr: 9.0000e-04
# Epoch 20/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5121 - auc: 0.5697
# Epoch 20: auc did not improve from 0.57696
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5114 - auc: 0.5698 - val_loss: 0.5126 - val_auc: 0.5917 - lr: 9.0000e-04
# Epoch 21/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5119 - auc: 0.5714
# Epoch 21: auc did not improve from 0.57696
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5114 - auc: 0.5723 - val_loss: 0.5137 - val_auc: 0.5917 - lr: 8.1000e-04
#
# fold_2
#
# Epoch 1/100
# 240/246 [============================>.] - ETA: 0s - loss: 0.6096 - auc: 0.5171
# Epoch 1: auc did not improve from 0.57696
# 246/246 [==============================] - 5s 12ms/step - loss: 0.6081 - auc: 0.5177 - val_loss: 0.5312 - val_auc: 0.5575 - lr: 0.0010
# Epoch 2/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5231 - auc: 0.5430
# Epoch 2: auc did not improve from 0.57696
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5234 - auc: 0.5428 - val_loss: 0.5261 - val_auc: 0.5596 - lr: 0.0010
# Epoch 3/100
# 241/246 [============================>.] - ETA: 0s - loss: 0.5122 - auc: 0.5570
# Epoch 3: auc did not improve from 0.57696
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5122 - auc: 0.5566 - val_loss: 0.5219 - val_auc: 0.5820 - lr: 0.0010
# Epoch 4/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5096 - auc: 0.5640
# Epoch 4: auc did not improve from 0.57696
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5100 - auc: 0.5654 - val_loss: 0.5206 - val_auc: 0.5769 - lr: 0.0010
# Epoch 5/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5097 - auc: 0.5633
# Epoch 5: auc did not improve from 0.57696
# 246/246 [==============================] - 2s 9ms/step - loss: 0.5097 - auc: 0.5633 - val_loss: 0.5209 - val_auc: 0.5800 - lr: 0.0010
# Epoch 6/100
# 240/246 [============================>.] - ETA: 0s - loss: 0.5082 - auc: 0.5697
# Epoch 6: auc did not improve from 0.57696
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5079 - auc: 0.5703 - val_loss: 0.5204 - val_auc: 0.5860 - lr: 0.0010
# Epoch 7/100
# 241/246 [============================>.] - ETA: 0s - loss: 0.5082 - auc: 0.5689
# Epoch 7: auc did not improve from 0.57696
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5076 - auc: 0.5688 - val_loss: 0.5199 - val_auc: 0.5770 - lr: 0.0010
# Epoch 8/100
# 241/246 [============================>.] - ETA: 0s - loss: 0.5052 - auc: 0.5706
# Epoch 8: auc did not improve from 0.57696
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5072 - auc: 0.5708 - val_loss: 0.5194 - val_auc: 0.5821 - lr: 0.0010
# Epoch 9/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5051 - auc: 0.5791
# Epoch 9: auc improved from 0.57696 to 0.58012, saving model to best.h5
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5055 - auc: 0.5801 - val_loss: 0.5217 - val_auc: 0.5837 - lr: 0.0010
# Epoch 10/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5072 - auc: 0.5714
# Epoch 10: auc did not improve from 0.58012
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5072 - auc: 0.5714 - val_loss: 0.5175 - val_auc: 0.5883 - lr: 0.0010
# Epoch 11/100
# 241/246 [============================>.] - ETA: 0s - loss: 0.5068 - auc: 0.5753
# Epoch 11: auc did not improve from 0.58012
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5066 - auc: 0.5742 - val_loss: 0.5194 - val_auc: 0.5833 - lr: 0.0010
# Epoch 12/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5068 - auc: 0.5691
# Epoch 12: auc did not improve from 0.58012
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5070 - auc: 0.5687 - val_loss: 0.5182 - val_auc: 0.5877 - lr: 0.0010
# Epoch 13/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5066 - auc: 0.5727
# Epoch 13: auc did not improve from 0.58012
# 246/246 [==============================] - 2s 9ms/step - loss: 0.5066 - auc: 0.5727 - val_loss: 0.5234 - val_auc: 0.5892 - lr: 0.0010
# Epoch 14/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5062 - auc: 0.5748
# Epoch 14: auc did not improve from 0.58012
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5062 - auc: 0.5748 - val_loss: 0.5179 - val_auc: 0.5892 - lr: 0.0010
# Epoch 15/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5062 - auc: 0.5752
# Epoch 15: auc did not improve from 0.58012
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5062 - auc: 0.5752 - val_loss: 0.5184 - val_auc: 0.5897 - lr: 9.0000e-04
# Epoch 16/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5059 - auc: 0.5766
# Epoch 16: auc did not improve from 0.58012
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5059 - auc: 0.5765 - val_loss: 0.5175 - val_auc: 0.5888 - lr: 9.0000e-04
# Epoch 17/100
# 240/246 [============================>.] - ETA: 0s - loss: 0.5073 - auc: 0.5744
# Epoch 17: auc did not improve from 0.58012
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5061 - auc: 0.5763 - val_loss: 0.5178 - val_auc: 0.5887 - lr: 9.0000e-04
# Epoch 18/100
# 240/246 [============================>.] - ETA: 0s - loss: 0.5056 - auc: 0.5825
# Epoch 18: auc improved from 0.58012 to 0.58206, saving model to best.h5
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5052 - auc: 0.5821 - val_loss: 0.5205 - val_auc: 0.5890 - lr: 9.0000e-04
# Epoch 19/100
# 241/246 [============================>.] - ETA: 0s - loss: 0.5074 - auc: 0.5661
# Epoch 19: auc did not improve from 0.58206
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5074 - auc: 0.5661 - val_loss: 0.5193 - val_auc: 0.5858 - lr: 9.0000e-04
# Epoch 20/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5058 - auc: 0.5742
# Epoch 20: auc did not improve from 0.58206
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5063 - auc: 0.5749 - val_loss: 0.5201 - val_auc: 0.5886 - lr: 9.0000e-04
#
# fold_3
#
# Epoch 1/100
# 256/256 [==============================] - ETA: 0s - loss: 0.6050 - auc: 0.5231
# Epoch 1: auc did not improve from 0.58206
# 256/256 [==============================] - 5s 12ms/step - loss: 0.6050 - auc: 0.5231 - val_loss: 0.5357 - val_auc: 0.5063 - lr: 0.0010
# Epoch 2/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.5187 - auc: 0.5430
# Epoch 2: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5186 - auc: 0.5431 - val_loss: 0.5291 - val_auc: 0.5631 - lr: 0.0010
# Epoch 3/100
# 250/256 [============================>.] - ETA: 0s - loss: 0.5109 - auc: 0.5530
# Epoch 3: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5110 - auc: 0.5533 - val_loss: 0.5257 - val_auc: 0.5795 - lr: 0.0010
# Epoch 4/100
# 250/256 [============================>.] - ETA: 0s - loss: 0.5093 - auc: 0.5485
# Epoch 4: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5089 - auc: 0.5496 - val_loss: 0.5263 - val_auc: 0.5853 - lr: 0.0010
# Epoch 5/100
# 253/256 [============================>.] - ETA: 0s - loss: 0.5058 - auc: 0.5666
# Epoch 5: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5060 - auc: 0.5669 - val_loss: 0.5246 - val_auc: 0.5866 - lr: 0.0010
# Epoch 6/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5063 - auc: 0.5596
# Epoch 6: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5068 - auc: 0.5601 - val_loss: 0.5244 - val_auc: 0.5929 - lr: 0.0010
# Epoch 7/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5065 - auc: 0.5630
# Epoch 7: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5059 - auc: 0.5635 - val_loss: 0.5235 - val_auc: 0.5926 - lr: 0.0010
# Epoch 8/100
# 253/256 [============================>.] - ETA: 0s - loss: 0.5040 - auc: 0.5715
# Epoch 8: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5040 - auc: 0.5719 - val_loss: 0.5224 - val_auc: 0.5942 - lr: 0.0010
# Epoch 9/100
# 253/256 [============================>.] - ETA: 0s - loss: 0.5055 - auc: 0.5693
# Epoch 9: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5048 - auc: 0.5684 - val_loss: 0.5254 - val_auc: 0.5932 - lr: 0.0010
# Epoch 10/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5053 - auc: 0.5712
# Epoch 10: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5045 - auc: 0.5703 - val_loss: 0.5232 - val_auc: 0.5929 - lr: 0.0010
# Epoch 11/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5043 - auc: 0.5672
# Epoch 11: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5046 - auc: 0.5674 - val_loss: 0.5227 - val_auc: 0.5933 - lr: 0.0010
# Epoch 12/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5046 - auc: 0.5694
# Epoch 12: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5048 - auc: 0.5699 - val_loss: 0.5212 - val_auc: 0.5951 - lr: 0.0010
# Epoch 13/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5054 - auc: 0.5651
# Epoch 13: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5052 - auc: 0.5655 - val_loss: 0.5251 - val_auc: 0.5913 - lr: 0.0010
# Epoch 14/100
# 253/256 [============================>.] - ETA: 0s - loss: 0.5052 - auc: 0.5703
# Epoch 14: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5046 - auc: 0.5707 - val_loss: 0.5229 - val_auc: 0.5959 - lr: 9.0000e-04
# Epoch 15/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5051 - auc: 0.5724
# Epoch 15: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5041 - auc: 0.5727 - val_loss: 0.5238 - val_auc: 0.5957 - lr: 9.0000e-04
# Epoch 16/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5059 - auc: 0.5613
# Epoch 16: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5056 - auc: 0.5607 - val_loss: 0.5226 - val_auc: 0.5960 - lr: 9.0000e-04
# Epoch 17/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.5049 - auc: 0.5660
# Epoch 17: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5050 - auc: 0.5659 - val_loss: 0.5216 - val_auc: 0.5953 - lr: 9.0000e-04
# Epoch 18/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5046 - auc: 0.5675
# Epoch 18: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5046 - auc: 0.5673 - val_loss: 0.5216 - val_auc: 0.5939 - lr: 9.0000e-04
# Epoch 19/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5059 - auc: 0.5594
# Epoch 19: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5055 - auc: 0.5598 - val_loss: 0.5260 - val_auc: 0.5933 - lr: 9.0000e-04
# Epoch 20/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5056 - auc: 0.5638
# Epoch 20: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5054 - auc: 0.5641 - val_loss: 0.5252 - val_auc: 0.5938 - lr: 9.0000e-04
# Epoch 21/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5043 - auc: 0.5729
# Epoch 21: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5042 - auc: 0.5720 - val_loss: 0.5212 - val_auc: 0.5950 - lr: 8.1000e-04
# Epoch 22/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5045 - auc: 0.5699
# Epoch 22: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5045 - auc: 0.5699 - val_loss: 0.5234 - val_auc: 0.5957 - lr: 8.1000e-04
# Epoch 23/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5045 - auc: 0.5689
# Epoch 23: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5047 - auc: 0.5691 - val_loss: 0.5220 - val_auc: 0.5945 - lr: 8.1000e-04
# Epoch 24/100
# 253/256 [============================>.] - ETA: 0s - loss: 0.5058 - auc: 0.5607
# Epoch 24: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5059 - auc: 0.5612 - val_loss: 0.5228 - val_auc: 0.5957 - lr: 8.1000e-04
# Epoch 25/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5058 - auc: 0.5644
# Epoch 25: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5057 - auc: 0.5647 - val_loss: 0.5225 - val_auc: 0.5957 - lr: 8.1000e-04
# Epoch 26/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5051 - auc: 0.5673
# Epoch 26: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5050 - auc: 0.5670 - val_loss: 0.5218 - val_auc: 0.5957 - lr: 7.2900e-04
# Epoch 27/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.5053 - auc: 0.5675
# Epoch 27: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5051 - auc: 0.5675 - val_loss: 0.5245 - val_auc: 0.5943 - lr: 7.2900e-04
# Epoch 28/100
# 250/256 [============================>.] - ETA: 0s - loss: 0.5041 - auc: 0.5709
# Epoch 28: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5046 - auc: 0.5719 - val_loss: 0.5206 - val_auc: 0.5953 - lr: 7.2900e-04
# Epoch 29/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5038 - auc: 0.5723
# Epoch 29: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5046 - auc: 0.5722 - val_loss: 0.5219 - val_auc: 0.5948 - lr: 7.2900e-04
# Epoch 30/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5049 - auc: 0.5688
# Epoch 30: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5049 - auc: 0.5688 - val_loss: 0.5224 - val_auc: 0.5949 - lr: 7.2900e-04
# Epoch 31/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5060 - auc: 0.5663
# Epoch 31: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5053 - auc: 0.5667 - val_loss: 0.5228 - val_auc: 0.5957 - lr: 6.5610e-04
# Epoch 32/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5054 - auc: 0.5648
# Epoch 32: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5057 - auc: 0.5642 - val_loss: 0.5212 - val_auc: 0.5948 - lr: 6.5610e-04
# Epoch 33/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5054 - auc: 0.5666
# Epoch 33: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5053 - auc: 0.5659 - val_loss: 0.5227 - val_auc: 0.5932 - lr: 6.5610e-04
# Epoch 34/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5053 - auc: 0.5662
# Epoch 34: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5055 - auc: 0.5662 - val_loss: 0.5228 - val_auc: 0.5947 - lr: 6.5610e-04
# Epoch 35/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5050 - auc: 0.5708
# Epoch 35: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5045 - auc: 0.5716 - val_loss: 0.5216 - val_auc: 0.5936 - lr: 6.5610e-04
# Epoch 36/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5040 - auc: 0.5649
# Epoch 36: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5053 - auc: 0.5655 - val_loss: 0.5230 - val_auc: 0.5950 - lr: 5.9049e-04
# Epoch 37/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5053 - auc: 0.5685
# Epoch 37: auc did not improve from 0.58206
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5053 - auc: 0.5682 - val_loss: 0.5255 - val_auc: 0.5951 - lr: 5.9049e-04
# Epoch 38/100
# 253/256 [============================>.] - ETA: 0s - loss: 0.5052 - auc: 0.5653
# Epoch 38: auc did not improve from 0.58206
# 256/256 [==============================] - 3s 13ms/step - loss: 0.5057 - auc: 0.5639 - val_loss: 0.5217 - val_auc: 0.5946 - lr: 5.9049e-04
#
# fold_4
#
# Epoch 1/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.6124 - auc: 0.5180
# Epoch 1: auc did not improve from 0.58206
# 252/252 [==============================] - 5s 12ms/step - loss: 0.6121 - auc: 0.5170 - val_loss: 0.5460 - val_auc: 0.5220 - lr: 0.0010
# Epoch 2/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5262 - auc: 0.5382
# Epoch 2: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5262 - auc: 0.5370 - val_loss: 0.5285 - val_auc: 0.5713 - lr: 0.0010
# Epoch 3/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5159 - auc: 0.5519
# Epoch 3: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5158 - auc: 0.5524 - val_loss: 0.5231 - val_auc: 0.5737 - lr: 0.0010
# Epoch 4/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5128 - auc: 0.5603
# Epoch 4: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5125 - auc: 0.5613 - val_loss: 0.5191 - val_auc: 0.5776 - lr: 0.0010
# Epoch 5/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5109 - auc: 0.5624
# Epoch 5: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5115 - auc: 0.5622 - val_loss: 0.5197 - val_auc: 0.5819 - lr: 0.0010
# Epoch 6/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5097 - auc: 0.5697
# Epoch 6: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5097 - auc: 0.5697 - val_loss: 0.5184 - val_auc: 0.5854 - lr: 0.0010
# Epoch 7/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5084 - auc: 0.5768
# Epoch 7: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5084 - auc: 0.5768 - val_loss: 0.5160 - val_auc: 0.5857 - lr: 0.0010
# Epoch 8/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5097 - auc: 0.5716
# Epoch 8: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5092 - auc: 0.5727 - val_loss: 0.5172 - val_auc: 0.5846 - lr: 0.0010
# Epoch 9/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5093 - auc: 0.5713
# Epoch 9: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5093 - auc: 0.5713 - val_loss: 0.5167 - val_auc: 0.5887 - lr: 0.0010
# Epoch 10/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5081 - auc: 0.5724
# Epoch 10: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5084 - auc: 0.5734 - val_loss: 0.5173 - val_auc: 0.5895 - lr: 0.0010
# Epoch 11/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5088 - auc: 0.5730
# Epoch 11: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5083 - auc: 0.5744 - val_loss: 0.5181 - val_auc: 0.5882 - lr: 0.0010
# Epoch 12/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5089 - auc: 0.5734
# Epoch 12: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5085 - auc: 0.5739 - val_loss: 0.5183 - val_auc: 0.5895 - lr: 0.0010
# Epoch 13/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5083 - auc: 0.5703
# Epoch 13: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5086 - auc: 0.5703 - val_loss: 0.5165 - val_auc: 0.5888 - lr: 9.0000e-04
# Epoch 14/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5083 - auc: 0.5721
# Epoch 14: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5084 - auc: 0.5722 - val_loss: 0.5169 - val_auc: 0.5877 - lr: 9.0000e-04
# Epoch 15/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5078 - auc: 0.5769
# Epoch 15: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5078 - auc: 0.5769 - val_loss: 0.5175 - val_auc: 0.5878 - lr: 9.0000e-04
# Epoch 16/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5082 - auc: 0.5713
# Epoch 16: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5086 - auc: 0.5707 - val_loss: 0.5168 - val_auc: 0.5912 - lr: 9.0000e-04
# Epoch 17/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5100 - auc: 0.5712
# Epoch 17: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5090 - auc: 0.5710 - val_loss: 0.5156 - val_auc: 0.5883 - lr: 9.0000e-04
# Epoch 18/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5087 - auc: 0.5696
# Epoch 18: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5091 - auc: 0.5697 - val_loss: 0.5158 - val_auc: 0.5890 - lr: 8.1000e-04
# Epoch 19/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5083 - auc: 0.5723
# Epoch 19: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5083 - auc: 0.5723 - val_loss: 0.5159 - val_auc: 0.5878 - lr: 8.1000e-04
# Epoch 20/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5080 - auc: 0.5764
# Epoch 20: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5080 - auc: 0.5764 - val_loss: 0.5168 - val_auc: 0.5837 - lr: 8.1000e-04
# Epoch 21/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5087 - auc: 0.5747
# Epoch 21: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5085 - auc: 0.5742 - val_loss: 0.5209 - val_auc: 0.5894 - lr: 8.1000e-04
# Epoch 22/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5088 - auc: 0.5715
# Epoch 22: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5088 - auc: 0.5715 - val_loss: 0.5165 - val_auc: 0.5880 - lr: 8.1000e-04
# Epoch 23/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5098 - auc: 0.5656
# Epoch 23: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5096 - auc: 0.5668 - val_loss: 0.5188 - val_auc: 0.5878 - lr: 7.2900e-04
# Epoch 24/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5089 - auc: 0.5724
# Epoch 24: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5086 - auc: 0.5736 - val_loss: 0.5157 - val_auc: 0.5879 - lr: 7.2900e-04
# Epoch 25/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5090 - auc: 0.5730
# Epoch 25: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5090 - auc: 0.5730 - val_loss: 0.5152 - val_auc: 0.5891 - lr: 7.2900e-04
# Epoch 26/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5094 - auc: 0.5689
# Epoch 26: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5094 - auc: 0.5685 - val_loss: 0.5156 - val_auc: 0.5895 - lr: 7.2900e-04
# Epoch 27/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5089 - auc: 0.5716
# Epoch 27: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5090 - auc: 0.5715 - val_loss: 0.5153 - val_auc: 0.5887 - lr: 7.2900e-04
# Epoch 28/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5079 - auc: 0.5794
# Epoch 28: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5081 - auc: 0.5787 - val_loss: 0.5155 - val_auc: 0.5892 - lr: 6.5610e-04
# Epoch 29/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5100 - auc: 0.5754
# Epoch 29: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5084 - auc: 0.5757 - val_loss: 0.5158 - val_auc: 0.5877 - lr: 6.5610e-04
# Epoch 30/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5092 - auc: 0.5644
# Epoch 30: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5095 - auc: 0.5651 - val_loss: 0.5167 - val_auc: 0.5889 - lr: 6.5610e-04
# Epoch 31/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5086 - auc: 0.5685
# Epoch 31: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5091 - auc: 0.5684 - val_loss: 0.5150 - val_auc: 0.5891 - lr: 6.5610e-04
# Epoch 32/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5093 - auc: 0.5716
# Epoch 32: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5088 - auc: 0.5722 - val_loss: 0.5190 - val_auc: 0.5882 - lr: 6.5610e-04
# Epoch 33/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5078 - auc: 0.5795
# Epoch 33: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5077 - auc: 0.5794 - val_loss: 0.5201 - val_auc: 0.5889 - lr: 6.5610e-04
# Epoch 34/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5083 - auc: 0.5771
# Epoch 34: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5080 - auc: 0.5778 - val_loss: 0.5224 - val_auc: 0.5858 - lr: 6.5610e-04
# Epoch 35/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5088 - auc: 0.5725
# Epoch 35: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5088 - auc: 0.5725 - val_loss: 0.5169 - val_auc: 0.5892 - lr: 6.5610e-04
# Epoch 36/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5084 - auc: 0.5737
# Epoch 36: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5085 - auc: 0.5735 - val_loss: 0.5176 - val_auc: 0.5869 - lr: 6.5610e-04
# Epoch 37/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5084 - auc: 0.5749
# Epoch 37: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5085 - auc: 0.5749 - val_loss: 0.5167 - val_auc: 0.5856 - lr: 6.5610e-04
# Epoch 38/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5094 - auc: 0.5732
# Epoch 38: auc did not improve from 0.58206
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5091 - auc: 0.5729 - val_loss: 0.5211 - val_auc: 0.5870 - lr: 6.5610e-04
# Epoch 39/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5084 - auc: 0.5727
# Epoch 39: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5085 - auc: 0.5731 - val_loss: 0.5160 - val_auc: 0.5895 - lr: 5.9049e-04
# Epoch 40/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5093 - auc: 0.5752
# Epoch 40: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5085 - auc: 0.5765 - val_loss: 0.5165 - val_auc: 0.5879 - lr: 5.9049e-04
# Epoch 41/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5096 - auc: 0.5765
# Epoch 41: auc did not improve from 0.58206
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5084 - auc: 0.5754 - val_loss: 0.5211 - val_auc: 0.5895 - lr: 5.9049e-04
#
# fold_5
#
# Epoch 1/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.6112 - auc: 0.5320
# Epoch 1: auc did not improve from 0.58206
# 244/244 [==============================] - 4s 11ms/step - loss: 0.6111 - auc: 0.5321 - val_loss: 0.5256 - val_auc: 0.5135 - lr: 0.0010
# Epoch 2/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5350 - auc: 0.5335
# Epoch 2: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5346 - auc: 0.5343 - val_loss: 0.5127 - val_auc: 0.5584 - lr: 0.0010
# Epoch 3/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.5225 - auc: 0.5687
# Epoch 3: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 10ms/step - loss: 0.5225 - auc: 0.5691 - val_loss: 0.5079 - val_auc: 0.5612 - lr: 0.0010
# Epoch 4/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.5217 - auc: 0.5611
# Epoch 4: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5217 - auc: 0.5612 - val_loss: 0.5050 - val_auc: 0.5716 - lr: 0.0010
# Epoch 5/100
# 238/244 [============================>.] - ETA: 0s - loss: 0.5219 - auc: 0.5591
# Epoch 5: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5217 - auc: 0.5585 - val_loss: 0.5063 - val_auc: 0.5856 - lr: 0.0010
# Epoch 6/100
# 238/244 [============================>.] - ETA: 0s - loss: 0.5193 - auc: 0.5677
# Epoch 6: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5194 - auc: 0.5669 - val_loss: 0.5078 - val_auc: 0.5771 - lr: 0.0010
# Epoch 7/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.5199 - auc: 0.5629
# Epoch 7: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 10ms/step - loss: 0.5197 - auc: 0.5627 - val_loss: 0.5060 - val_auc: 0.5785 - lr: 0.0010
# Epoch 8/100
# 238/244 [============================>.] - ETA: 0s - loss: 0.5184 - auc: 0.5756
# Epoch 8: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5177 - auc: 0.5751 - val_loss: 0.5034 - val_auc: 0.5861 - lr: 0.0010
# Epoch 9/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.5178 - auc: 0.5713
# Epoch 9: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5180 - auc: 0.5717 - val_loss: 0.5072 - val_auc: 0.5827 - lr: 0.0010
# Epoch 10/100
# 238/244 [============================>.] - ETA: 0s - loss: 0.5184 - auc: 0.5711
# Epoch 10: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5187 - auc: 0.5720 - val_loss: 0.5060 - val_auc: 0.5793 - lr: 0.0010
# Epoch 11/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.5189 - auc: 0.5744
# Epoch 11: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5182 - auc: 0.5746 - val_loss: 0.5012 - val_auc: 0.5871 - lr: 0.0010
# Epoch 12/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.5168 - auc: 0.5777
# Epoch 12: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5173 - auc: 0.5776 - val_loss: 0.5024 - val_auc: 0.5871 - lr: 0.0010
# Epoch 13/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5183 - auc: 0.5721
# Epoch 13: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 10ms/step - loss: 0.5180 - auc: 0.5719 - val_loss: 0.5053 - val_auc: 0.5869 - lr: 0.0010
# Epoch 14/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.5182 - auc: 0.5714
# Epoch 14: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5182 - auc: 0.5714 - val_loss: 0.5023 - val_auc: 0.5882 - lr: 0.0010
# Epoch 15/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5175 - auc: 0.5754
# Epoch 15: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 10ms/step - loss: 0.5174 - auc: 0.5752 - val_loss: 0.5125 - val_auc: 0.5872 - lr: 0.0010
# Epoch 16/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5172 - auc: 0.5757
# Epoch 16: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5176 - auc: 0.5755 - val_loss: 0.5022 - val_auc: 0.5868 - lr: 0.0010
# Epoch 17/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.5183 - auc: 0.5693
# Epoch 17: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5185 - auc: 0.5691 - val_loss: 0.5043 - val_auc: 0.5872 - lr: 0.0010
# Epoch 18/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.5185 - auc: 0.5697
# Epoch 18: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 10ms/step - loss: 0.5187 - auc: 0.5691 - val_loss: 0.5046 - val_auc: 0.5860 - lr: 9.0000e-04
# Epoch 19/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.5168 - auc: 0.5781
# Epoch 19: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5169 - auc: 0.5775 - val_loss: 0.5060 - val_auc: 0.5878 - lr: 9.0000e-04
# Epoch 20/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.5179 - auc: 0.5718
# Epoch 20: auc did not improve from 0.58206
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5184 - auc: 0.5719 - val_loss: 0.5043 - val_auc: 0.5894 - lr: 9.0000e-04
# Epoch 21/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.5173 - auc: 0.5762
# Epoch 21: auc did not improve from 0.58206
# 244/244 [==============================] - 3s 10ms/step - loss: 0.5174 - auc: 0.5769 - val_loss: 0.5036 - val_auc: 0.5870 - lr: 9.0000e-04
#
# fold_6
#
# Epoch 1/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.6035 - auc: 0.5321
# Epoch 1: auc did not improve from 0.58206
# 254/254 [==============================] - 5s 12ms/step - loss: 0.6035 - auc: 0.5306 - val_loss: 0.5279 - val_auc: 0.5511 - lr: 0.0010
# Epoch 2/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5311 - auc: 0.5345
# Epoch 2: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5304 - auc: 0.5351 - val_loss: 0.5143 - val_auc: 0.5723 - lr: 0.0010
# Epoch 3/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5222 - auc: 0.5482
# Epoch 3: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5224 - auc: 0.5478 - val_loss: 0.5109 - val_auc: 0.5750 - lr: 0.0010
# Epoch 4/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5172 - auc: 0.5668
# Epoch 4: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5177 - auc: 0.5665 - val_loss: 0.5078 - val_auc: 0.5880 - lr: 0.0010
# Epoch 5/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5177 - auc: 0.5662
# Epoch 5: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5174 - auc: 0.5661 - val_loss: 0.5068 - val_auc: 0.5867 - lr: 0.0010
# Epoch 6/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5158 - auc: 0.5726
# Epoch 6: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5161 - auc: 0.5718 - val_loss: 0.5080 - val_auc: 0.5723 - lr: 0.0010
# Epoch 7/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5162 - auc: 0.5656
# Epoch 7: auc did not improve from 0.58206
# 254/254 [==============================] - 4s 16ms/step - loss: 0.5163 - auc: 0.5659 - val_loss: 0.5080 - val_auc: 0.5872 - lr: 0.0010
# Epoch 8/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5158 - auc: 0.5696
# Epoch 8: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5159 - auc: 0.5699 - val_loss: 0.5109 - val_auc: 0.5919 - lr: 0.0010
# Epoch 9/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5157 - auc: 0.5708
# Epoch 9: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5157 - auc: 0.5708 - val_loss: 0.5060 - val_auc: 0.5940 - lr: 0.0010
# Epoch 10/100
# 252/254 [============================>.] - ETA: 0s - loss: 0.5147 - auc: 0.5741
# Epoch 10: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5150 - auc: 0.5745 - val_loss: 0.5083 - val_auc: 0.5918 - lr: 0.0010
# Epoch 11/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5146 - auc: 0.5749
# Epoch 11: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5150 - auc: 0.5753 - val_loss: 0.5039 - val_auc: 0.5907 - lr: 0.0010
# Epoch 12/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5145 - auc: 0.5758
# Epoch 12: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5149 - auc: 0.5755 - val_loss: 0.5066 - val_auc: 0.5914 - lr: 0.0010
# Epoch 13/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5158 - auc: 0.5666
# Epoch 13: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5159 - auc: 0.5672 - val_loss: 0.5064 - val_auc: 0.5919 - lr: 0.0010
# Epoch 14/100
# 252/254 [============================>.] - ETA: 0s - loss: 0.5149 - auc: 0.5699
# Epoch 14: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5153 - auc: 0.5708 - val_loss: 0.5076 - val_auc: 0.5937 - lr: 0.0010
# Epoch 15/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5146 - auc: 0.5767
# Epoch 15: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5144 - auc: 0.5773 - val_loss: 0.5041 - val_auc: 0.5904 - lr: 0.0010
# Epoch 16/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5148 - auc: 0.5736
# Epoch 16: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5150 - auc: 0.5733 - val_loss: 0.5048 - val_auc: 0.5904 - lr: 0.0010
# Epoch 17/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5150 - auc: 0.5718
# Epoch 17: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5151 - auc: 0.5717 - val_loss: 0.5047 - val_auc: 0.5918 - lr: 0.0010
# Epoch 18/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5152 - auc: 0.5715
# Epoch 18: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5152 - auc: 0.5717 - val_loss: 0.5113 - val_auc: 0.5919 - lr: 0.0010
# Epoch 19/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5150 - auc: 0.5681
# Epoch 19: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5152 - auc: 0.5680 - val_loss: 0.5100 - val_auc: 0.5913 - lr: 0.0010
# Epoch 20/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5154 - auc: 0.5705
# Epoch 20: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5154 - auc: 0.5705 - val_loss: 0.5145 - val_auc: 0.5934 - lr: 0.0010
# Epoch 21/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5153 - auc: 0.5705
# Epoch 21: auc did not improve from 0.58206
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5150 - auc: 0.5707 - val_loss: 0.5122 - val_auc: 0.5899 - lr: 9.0000e-04
#
# fold_7
#
# Epoch 1/100
# 247/250 [============================>.] - ETA: 0s - loss: 0.6152 - auc: 0.5238
# Epoch 1: auc did not improve from 0.58206
# 250/250 [==============================] - 5s 12ms/step - loss: 0.6145 - auc: 0.5237 - val_loss: 0.5228 - val_auc: 0.5430 - lr: 0.0010
# Epoch 2/100
# 248/250 [============================>.] - ETA: 0s - loss: 0.5329 - auc: 0.5486
# Epoch 2: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5330 - auc: 0.5485 - val_loss: 0.5126 - val_auc: 0.5612 - lr: 0.0010
# Epoch 3/100
# 248/250 [============================>.] - ETA: 0s - loss: 0.5245 - auc: 0.5580
# Epoch 3: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5244 - auc: 0.5573 - val_loss: 0.5077 - val_auc: 0.5703 - lr: 0.0010
# Epoch 4/100
# 244/250 [============================>.] - ETA: 0s - loss: 0.5220 - auc: 0.5668
# Epoch 4: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5219 - auc: 0.5670 - val_loss: 0.5040 - val_auc: 0.5712 - lr: 0.0010
# Epoch 5/100
# 247/250 [============================>.] - ETA: 0s - loss: 0.5226 - auc: 0.5644
# Epoch 5: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5217 - auc: 0.5642 - val_loss: 0.5040 - val_auc: 0.5551 - lr: 0.0010
# Epoch 6/100
# 248/250 [============================>.] - ETA: 0s - loss: 0.5200 - auc: 0.5726
# Epoch 6: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5200 - auc: 0.5729 - val_loss: 0.5042 - val_auc: 0.5519 - lr: 0.0010
# Epoch 7/100
# 247/250 [============================>.] - ETA: 0s - loss: 0.5203 - auc: 0.5754
# Epoch 7: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5199 - auc: 0.5749 - val_loss: 0.5006 - val_auc: 0.5886 - lr: 0.0010
# Epoch 8/100
# 245/250 [============================>.] - ETA: 0s - loss: 0.5192 - auc: 0.5762
# Epoch 8: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5187 - auc: 0.5761 - val_loss: 0.5025 - val_auc: 0.5763 - lr: 0.0010
# Epoch 9/100
# 244/250 [============================>.] - ETA: 0s - loss: 0.5200 - auc: 0.5702
# Epoch 9: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5201 - auc: 0.5702 - val_loss: 0.5110 - val_auc: 0.5836 - lr: 0.0010
# Epoch 10/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5199 - auc: 0.5729
# Epoch 10: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5199 - auc: 0.5729 - val_loss: 0.5005 - val_auc: 0.5872 - lr: 0.0010
# Epoch 11/100
# 247/250 [============================>.] - ETA: 0s - loss: 0.5191 - auc: 0.5734
# Epoch 11: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5193 - auc: 0.5739 - val_loss: 0.5071 - val_auc: 0.5859 - lr: 0.0010
# Epoch 12/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5191 - auc: 0.5741
# Epoch 12: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5191 - auc: 0.5741 - val_loss: 0.5010 - val_auc: 0.5866 - lr: 0.0010
# Epoch 13/100
# 248/250 [============================>.] - ETA: 0s - loss: 0.5196 - auc: 0.5767
# Epoch 13: auc did not improve from 0.58206
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5190 - auc: 0.5769 - val_loss: 0.5004 - val_auc: 0.5849 - lr: 0.0010
# Epoch 14/100
# ...
# Epoch 15: auc did not improve from 0.58206
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5106 - auc: 0.5733 - val_loss: 0.5190 - val_auc: 0.5902 - lr: 9.0000e-04
# Epoch 16/100
# 240/246 [============================>.] - ETA: 0s - loss: 0.5104 - auc: 0.5769
# Epoch 16: auc did not improve from 0.58206
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5101 - auc: 0.5760 - val_loss: 0.5116 - val_auc: 0.5871 - lr: 9.0000e-04
# Epoch 17/100
# 244/246 [============================>.] - ETA: 0s - loss: 0.5096 - auc: 0.5798
# Epoch 17: auc did not improve from 0.58206
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5098 - auc: 0.5801 - val_loss: 0.5137 - val_auc: 0.5875 - lr: 8.1000e-04
# Epoch 18/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5095 - auc: 0.5784
# Epoch 18: auc did not improve from 0.58206
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5102 - auc: 0.5777 - val_loss: 0.5176 - val_auc: 0.5896 - lr: 8.1000e-04
# Epoch 19/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5112 - auc: 0.5685
# Epoch 19: auc did not improve from 0.58206
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5112 - auc: 0.5685 - val_loss: 0.5173 - val_auc: 0.5884 - lr: 8.1000e-04
# Epoch 20/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5118 - auc: 0.5686
# Epoch 20: auc did not improve from 0.58206
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5113 - auc: 0.5694 - val_loss: 0.5122 - val_auc: 0.5876 - lr: 8.1000e-04
#
# fold_9
#
# Epoch 1/100
# 236/242 [============================>.] - ETA: 0s - loss: 0.6114 - auc: 0.5278
# Epoch 1: auc did not improve from 0.58206
# 242/242 [==============================] - 5s 13ms/step - loss: 0.6096 - auc: 0.5286 - val_loss: 0.5295 - val_auc: 0.5500 - lr: 0.0010
# Epoch 2/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5323 - auc: 0.5418
# Epoch 2: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 10ms/step - loss: 0.5324 - auc: 0.5411 - val_loss: 0.5173 - val_auc: 0.5595 - lr: 0.0010
# Epoch 3/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5211 - auc: 0.5603
# Epoch 3: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5217 - auc: 0.5599 - val_loss: 0.5093 - val_auc: 0.5766 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5178 - auc: 0.5698
# Epoch 4: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5181 - auc: 0.5695 - val_loss: 0.5127 - val_auc: 0.5773 - lr: 0.0010
# Epoch 5/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5183 - auc: 0.5690
# Epoch 5: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5174 - auc: 0.5695 - val_loss: 0.5103 - val_auc: 0.5808 - lr: 0.0010
# Epoch 6/100
# 238/242 [============================>.] - ETA: 0s - loss: 0.5157 - auc: 0.5746
# Epoch 6: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5155 - auc: 0.5750 - val_loss: 0.5104 - val_auc: 0.5835 - lr: 0.0010
# Epoch 7/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5162 - auc: 0.5777
# Epoch 7: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 12ms/step - loss: 0.5151 - auc: 0.5783 - val_loss: 0.5109 - val_auc: 0.5804 - lr: 0.0010
# Epoch 8/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5133 - auc: 0.5800
# Epoch 8: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5144 - auc: 0.5799 - val_loss: 0.5089 - val_auc: 0.5847 - lr: 0.0010
# Epoch 9/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5144 - auc: 0.5768
# Epoch 9: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5145 - auc: 0.5765 - val_loss: 0.5090 - val_auc: 0.5814 - lr: 0.0010
# Epoch 10/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5152 - auc: 0.5721
# Epoch 10: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5154 - auc: 0.5728 - val_loss: 0.5120 - val_auc: 0.5831 - lr: 0.0010
# Epoch 11/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5150 - auc: 0.5733
# Epoch 11: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5153 - auc: 0.5727 - val_loss: 0.5095 - val_auc: 0.5851 - lr: 0.0010
# Epoch 12/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5143 - auc: 0.5791
# Epoch 12: auc did not improve from 0.58206
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5144 - auc: 0.5799 - val_loss: 0.5084 - val_auc: 0.5844 - lr: 0.0010
# Epoch 13/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5138 - auc: 0.5833
# Epoch 13: auc improved from 0.58206 to 0.58422, saving model to best.h5
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5136 - auc: 0.5842 - val_loss: 0.5165 - val_auc: 0.5847 - lr: 0.0010
# Epoch 14/100
# 240/242 [============================>.] - ETA: 0s - loss: 0.5158 - auc: 0.5689
# Epoch 14: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5154 - auc: 0.5693 - val_loss: 0.5064 - val_auc: 0.5845 - lr: 0.0010
# Epoch 15/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5148 - auc: 0.5749
# Epoch 15: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 12ms/step - loss: 0.5147 - auc: 0.5750 - val_loss: 0.5080 - val_auc: 0.5843 - lr: 0.0010
# Epoch 16/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5159 - auc: 0.5655
# Epoch 16: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5157 - auc: 0.5669 - val_loss: 0.5103 - val_auc: 0.5845 - lr: 0.0010
# Epoch 17/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5146 - auc: 0.5787
# Epoch 17: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 14ms/step - loss: 0.5142 - auc: 0.5790 - val_loss: 0.5070 - val_auc: 0.5827 - lr: 0.0010
# Epoch 18/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5139 - auc: 0.5823
# Epoch 18: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 13ms/step - loss: 0.5140 - auc: 0.5815 - val_loss: 0.5062 - val_auc: 0.5842 - lr: 0.0010
# Epoch 19/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5142 - auc: 0.5749
# Epoch 19: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5151 - auc: 0.5743 - val_loss: 0.5083 - val_auc: 0.5832 - lr: 9.0000e-04
# Epoch 20/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5149 - auc: 0.5761
# Epoch 20: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 10ms/step - loss: 0.5147 - auc: 0.5761 - val_loss: 0.5079 - val_auc: 0.5846 - lr: 9.0000e-04
# Epoch 21/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5148 - auc: 0.5746
# Epoch 21: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5149 - auc: 0.5748 - val_loss: 0.5092 - val_auc: 0.5853 - lr: 9.0000e-04
# Epoch 22/100
# 240/242 [============================>.] - ETA: 0s - loss: 0.5139 - auc: 0.5786
# Epoch 22: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5142 - auc: 0.5789 - val_loss: 0.5090 - val_auc: 0.5842 - lr: 9.0000e-04
# Epoch 23/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5151 - auc: 0.5741
# Epoch 23: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5151 - auc: 0.5733 - val_loss: 0.5064 - val_auc: 0.5843 - lr: 9.0000e-04
# Epoch 24/100
# 238/242 [============================>.] - ETA: 0s - loss: 0.5158 - auc: 0.5665
# Epoch 24: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5158 - auc: 0.5678 - val_loss: 0.5104 - val_auc: 0.5849 - lr: 8.1000e-04
# Epoch 25/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5152 - auc: 0.5754
# Epoch 25: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5150 - auc: 0.5753 - val_loss: 0.5104 - val_auc: 0.5849 - lr: 8.1000e-04
# Epoch 26/100
# 238/242 [============================>.] - ETA: 0s - loss: 0.5158 - auc: 0.5761
# Epoch 26: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5145 - auc: 0.5766 - val_loss: 0.5082 - val_auc: 0.5835 - lr: 8.1000e-04
# Epoch 27/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5150 - auc: 0.5726
# Epoch 27: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5150 - auc: 0.5726 - val_loss: 0.5199 - val_auc: 0.5851 - lr: 8.1000e-04
# Epoch 28/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5145 - auc: 0.5763
# Epoch 28: auc did not improve from 0.58422
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5148 - auc: 0.5764 - val_loss: 0.5133 - val_auc: 0.5852 - lr: 8.1000e-04
#
# fold_10
#
# Epoch 1/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.6106 - auc: 0.5280
# Epoch 1: auc did not improve from 0.58422
# 252/252 [==============================] - 5s 12ms/step - loss: 0.6087 - auc: 0.5289 - val_loss: 0.5308 - val_auc: 0.5470 - lr: 0.0010
# Epoch 2/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5281 - auc: 0.5417
# Epoch 2: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5281 - auc: 0.5417 - val_loss: 0.5174 - val_auc: 0.5595 - lr: 0.0010
# Epoch 3/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5190 - auc: 0.5528
# Epoch 3: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5187 - auc: 0.5539 - val_loss: 0.5173 - val_auc: 0.5747 - lr: 0.0010
# Epoch 4/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5156 - auc: 0.5689
# Epoch 4: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5152 - auc: 0.5687 - val_loss: 0.5126 - val_auc: 0.5787 - lr: 0.0010
# Epoch 5/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5128 - auc: 0.5736
# Epoch 5: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5128 - auc: 0.5736 - val_loss: 0.5123 - val_auc: 0.5742 - lr: 0.0010
# Epoch 6/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5136 - auc: 0.5727
# Epoch 6: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5133 - auc: 0.5722 - val_loss: 0.5121 - val_auc: 0.5851 - lr: 0.0010
# Epoch 7/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5141 - auc: 0.5741
# Epoch 7: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5131 - auc: 0.5743 - val_loss: 0.5109 - val_auc: 0.5853 - lr: 0.0010
# Epoch 8/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5128 - auc: 0.5724
# Epoch 8: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5128 - auc: 0.5724 - val_loss: 0.5100 - val_auc: 0.5919 - lr: 0.0010
# Epoch 9/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5125 - auc: 0.5745
# Epoch 9: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5124 - auc: 0.5747 - val_loss: 0.5095 - val_auc: 0.5903 - lr: 0.0010
# Epoch 10/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5124 - auc: 0.5735
# Epoch 10: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5122 - auc: 0.5744 - val_loss: 0.5090 - val_auc: 0.5897 - lr: 0.0010
# Epoch 11/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5133 - auc: 0.5682
# Epoch 11: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5133 - auc: 0.5682 - val_loss: 0.5120 - val_auc: 0.5889 - lr: 0.0010
# Epoch 12/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5126 - auc: 0.5739
# Epoch 12: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5127 - auc: 0.5733 - val_loss: 0.5146 - val_auc: 0.5892 - lr: 0.0010
# Epoch 13/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5134 - auc: 0.5725
# Epoch 13: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5127 - auc: 0.5732 - val_loss: 0.5131 - val_auc: 0.5899 - lr: 0.0010
# Epoch 14/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5123 - auc: 0.5763
# Epoch 14: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5121 - auc: 0.5764 - val_loss: 0.5094 - val_auc: 0.5905 - lr: 0.0010
# Epoch 15/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5128 - auc: 0.5707
# Epoch 15: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5129 - auc: 0.5701 - val_loss: 0.5085 - val_auc: 0.5896 - lr: 0.0010
# Epoch 16/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5126 - auc: 0.5729
# Epoch 16: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5124 - auc: 0.5732 - val_loss: 0.5155 - val_auc: 0.5901 - lr: 0.0010
# Epoch 17/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5121 - auc: 0.5744
# Epoch 17: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5121 - auc: 0.5744 - val_loss: 0.5155 - val_auc: 0.5887 - lr: 0.0010
# Epoch 18/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5113 - auc: 0.5764
# Epoch 18: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5122 - auc: 0.5756 - val_loss: 0.5087 - val_auc: 0.5900 - lr: 0.0010
# Epoch 19/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5122 - auc: 0.5736
# Epoch 19: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5122 - auc: 0.5736 - val_loss: 0.5140 - val_auc: 0.5898 - lr: 0.0010
# Epoch 20/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5135 - auc: 0.5681
# Epoch 20: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5133 - auc: 0.5683 - val_loss: 0.5092 - val_auc: 0.5884 - lr: 9.0000e-04
# Epoch 21/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5118 - auc: 0.5767
# Epoch 21: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5120 - auc: 0.5759 - val_loss: 0.5087 - val_auc: 0.5883 - lr: 9.0000e-04
# Epoch 22/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5127 - auc: 0.5734
# Epoch 22: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5123 - auc: 0.5741 - val_loss: 0.5107 - val_auc: 0.5891 - lr: 9.0000e-04
# Epoch 23/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5139 - auc: 0.5643
# Epoch 23: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 13ms/step - loss: 0.5137 - auc: 0.5651 - val_loss: 0.5110 - val_auc: 0.5895 - lr: 9.0000e-04
# Epoch 24/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5125 - auc: 0.5744
# Epoch 24: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5125 - auc: 0.5747 - val_loss: 0.5140 - val_auc: 0.5896 - lr: 9.0000e-04
# Epoch 25/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5137 - auc: 0.5701
# Epoch 25: auc did not improve from 0.58422
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5132 - auc: 0.5701 - val_loss: 0.5104 - val_auc: 0.5901 - lr: 8.1000e-04

# %%
from google.colab import files
files.download('best.h5')
