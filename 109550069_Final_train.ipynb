# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install feature_engine
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feature_engine
#   Downloading feature_engine-1.5.2-py2.py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (1.7.3)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (0.12.2)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (1.3.5)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (1.0.2)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.8/dist-packages (from feature_engine) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.3->feature_engine) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.3->feature_engine) (2022.7)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.0->feature_engine) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.0->feature_engine) (3.1.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.11.1->feature_engine) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5->statsmodels>=0.11.1->feature_engine) (1.15.0)
# Installing collected packages: feature_engine
# Successfully installed feature_engine-1.5.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0

# %%
import numpy as np
import pandas as pd
import os
import sys

import joblib # saving sklearn modules
from sklearn.impute import KNNImputer # completing missing values using k-Nearest Neighbors
from feature_engine.encoding import WoEEncoder # encode only categorical variables (type ‘object’)
from sklearn.linear_model import LogisticRegression, HuberRegressor

from tensorflow.keras import Sequential  
from tensorflow.keras.layers import BatchNormalization, Dropout, Dense
import tensorflow as tf
from tensorflow_addons.optimizers import AdamW
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
Train = pd.read_csv('/content/drive/MyDrive/大三上作業/ML_final/train.csv')
Test = pd.read_csv('/content/drive/MyDrive/大三上作業/ML_final/test.csv')

# %%
data = pd.concat([Train, Test])
# create lists that will be used
codes = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
drops = ['id', 'product_code', 'loading', 'attribute_0', 'attribute_1', 'attribute_2', 'attribute_3', 'loading', 'missing3', 'missing5']
featureM = [f for f in data.columns if f.startswith('measurement') or f=='loading']
features = ['loading', 'attribute_0', 'measurement_17', 'measurement_0','measurement_1', 'measurement_2', 'attr23', 'missing3', 'missing5']

# create a dict for measurements 3-17 because they contain value lost (*reference)
measurements = {}
# set up measurement 17 manually
measurements['measurement_17'] = {
        'A': ['measurement_5','measurement_6','measurement_8','measurement_7'],
        'B': ['measurement_4','measurement_5','measurement_7','measurement_9'],
        'C': ['measurement_5','measurement_7','measurement_8','measurement_9'],
        'D': ['measurement_5','measurement_6','measurement_7','measurement_8'],
        'E': ['measurement_4','measurement_5','measurement_6','measurement_8'],
        'F': ['measurement_4','measurement_5','measurement_6','measurement_7'],
        'G': ['measurement_4','measurement_6','measurement_8','measurement_9'],
        'H': ['measurement_4','measurement_5','measurement_7','measurement_8','measurement_9'],
        'I': ['measurement_3','measurement_7','measurement_8','measurement_9']
    }

# when measurement_3 is missing, the failure rate is 0.160 (much lower than average)    
data['missing3'] = data['measurement_3'].isna().astype(np.int8)
# when measurement_5 is missing, the failure rate is 0.254 (much higher than average)
data['missing5'] = data['measurement_5'].isna().astype(np.int8)
# attribute_2 has two values (5 and 8) which occur only in the training data, and another value (7) occurs only in the test data, attribute_3 is similar.
data['attr23'] = data['attribute_2'] * data['attribute_3']

# get the correlation values of measurements 3-16
colName = []
value = []
for i in range(3,17):
    colName.append(f'measurement_{i}')
    corr = np.absolute(data.drop(drops, axis=1).corr()[f'measurement_{i}']).sort_values(ascending=False)
    value.append(np.sum(corr[1:4]))

# take the measurements in order of sorted correlation
measurementCorr = pd.DataFrame({'column name': colName, 'values': value})
sortedMeasurement = measurementCorr.sort_values(by='values', ascending=False).reset_index(drop=True)
for i in range(10): # only take the top 10
    whichMeasurement = sortedMeasurement.iloc[i, 0]
    best4 = {} # pick 4 measurements with best correlations for each product_code
    for c in codes: 
        corr = np.absolute(data[data.product_code == c].drop(drops, axis=1).corr()[whichMeasurement]).sort_values(ascending=False)
        best4[c] = corr[1:5].index.tolist()
    measurements[whichMeasurement] = best4 # measurement_i | product_code : measurement_i1, measurement_i2, measurement_i3, measurement_i4

# for each product_code
for code in codes:
    # fill the measurement columns with linear model
    for measure in list(measurements.keys()):
        dataM = data[data.product_code == code]
        best4 = measurements[measure][code] # product_code : measurement_i1, measurement_i2, measurement_i3, measurement_i4
        trainM = dataM[best4+[measure]].dropna(how='any') # 4 related + itself as target (all should not be null)
        testM = dataM[(dataM[best4].isnull().sum(axis=1)==0) & (dataM[measure].isnull())] # 4 related (no null) + itself as target (null)
        modelLinear = HuberRegressor(epsilon=1.75)
        modelLinear.fit(trainM[best4], trainM[measure])
        data.loc[(data.product_code==code)&(data[best4].isnull().sum(axis=1)==0)&(data[measure].isnull()), measure] = modelLinear.predict(testM[best4])
    # fill the others N/A columns with KNN (k=3)
    modelKnn = KNNImputer(n_neighbors=3)
    data.loc[data.product_code==code, featureM] = modelKnn.fit_transform(data.loc[data.product_code==code, featureM])

# encode attribute_0
train = data.iloc[:len(Train.index)]
encode = WoEEncoder(variables=['attribute_0'])
encode.fit(train, train['failure'])
train = encode.transform(train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
# first 3 codes for training, latter 2 for validation (*reference)
folds = {'fold_1': [['C', 'D', 'E'], ['A', 'B']], 
         'fold_2': [['B', 'D', 'E'], ['A', 'C']],
         'fold_3': [['B', 'C', 'E'], ['A', 'D']],
         'fold_4': [['B', 'C', 'D'], ['A', 'E']],
         'fold_5': [['A', 'D', 'E'], ['B', 'C']],
         'fold_6': [['A', 'C', 'E'], ['B', 'D']],
         'fold_7': [['A', 'C', 'D'], ['B', 'E']],
         'fold_8': [['A', 'B', 'E'], ['C', 'D']],
         'fold_9': [['A', 'B', 'D'], ['C', 'E']],
         'fold_10': [['A', 'B', 'C'], ['D', 'E']]}

tf.random.set_seed(85)
# set up the callbacks
bestModel = ModelCheckpoint('best.h5', verbose=1, save_best_only=True, monitor="auc", mode="max")
earlyStop = EarlyStopping(patience=10, restore_best_weights=True)
reduceLr = ReduceLROnPlateau(monitor="auc", factor=0.9, patience=5, mode="max", min_delta=0.0001)

# run through all the folds
for fold in folds.keys():
    print(f'\n{fold}\n')
    
    x_train, y_train = train[train['product_code'].isin(folds[fold][0])][features].values, train[train['product_code'].isin(folds[fold][0])]['failure'].values
    x_valid, y_valid = train[train['product_code'].isin(folds[fold][1])][features].values, train[train['product_code'].isin(folds[fold][1])]['failure'].values

    # create a new model for each fold
    model = Sequential()
    model.add(BatchNormalization())
    model.add(Dense(len(x_train), activation="relu"))
    model.add(BatchNormalization())
    model.add(Dense(128, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dense(64, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dense(32, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dense(16, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dense(1, activation="sigmoid"))

    model.compile(optimizer=AdamW(learning_rate=1e-3, weight_decay=1e-3), loss=BinaryCrossentropy(), metrics=["AUC"])
    model.fit(x_train, y_train, batch_size = 64, epochs = 100, callbacks=[earlyStop, reduceLr, bestModel], validation_data=(x_valid, y_valid))
# Out:
# fold_1
#
# Epoch 1/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.6024 - auc: 0.5395
# Epoch 1: auc improved from -inf to 0.53968, saving model to best.h5
# 254/254 [==============================] - 5s 11ms/step - loss: 0.6012 - auc: 0.5397 - val_loss: 0.5341 - val_auc: 0.5527 - lr: 0.0010
# Epoch 2/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5225 - auc: 0.5609
# Epoch 2: auc improved from 0.53968 to 0.56092, saving model to best.h5
# 254/254 [==============================] - 4s 16ms/step - loss: 0.5226 - auc: 0.5609 - val_loss: 0.5190 - val_auc: 0.5613 - lr: 0.0010
# Epoch 3/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5142 - auc: 0.5727
# Epoch 3: auc improved from 0.56092 to 0.57267, saving model to best.h5
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5142 - auc: 0.5727 - val_loss: 0.5189 - val_auc: 0.5508 - lr: 0.0010
# Epoch 4/100
# 252/254 [============================>.] - ETA: 0s - loss: 0.5119 - auc: 0.5806
# Epoch 4: auc improved from 0.57267 to 0.58032, saving model to best.h5
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5119 - auc: 0.5803 - val_loss: 0.5158 - val_auc: 0.5802 - lr: 0.0010
# Epoch 5/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5120 - auc: 0.5782
# Epoch 5: auc did not improve from 0.58032
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5121 - auc: 0.5783 - val_loss: 0.5116 - val_auc: 0.5867 - lr: 0.0010
# Epoch 6/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5108 - auc: 0.5802
# Epoch 6: auc did not improve from 0.58032
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5108 - auc: 0.5802 - val_loss: 0.5117 - val_auc: 0.5933 - lr: 0.0010
# Epoch 7/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5102 - auc: 0.5840
# Epoch 7: auc improved from 0.58032 to 0.58401, saving model to best.h5
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5101 - auc: 0.5840 - val_loss: 0.5130 - val_auc: 0.5924 - lr: 0.0010
# Epoch 8/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5100 - auc: 0.5838
# Epoch 8: auc did not improve from 0.58401
# 254/254 [==============================] - 3s 12ms/step - loss: 0.5099 - auc: 0.5838 - val_loss: 0.5150 - val_auc: 0.5871 - lr: 0.0010
# Epoch 9/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5095 - auc: 0.5880
# Epoch 9: auc improved from 0.58401 to 0.58758, saving model to best.h5
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5096 - auc: 0.5876 - val_loss: 0.5147 - val_auc: 0.5925 - lr: 0.0010
# Epoch 10/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5101 - auc: 0.5886
# Epoch 10: auc did not improve from 0.58758
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5095 - auc: 0.5875 - val_loss: 0.5222 - val_auc: 0.5929 - lr: 0.0010
# Epoch 11/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5094 - auc: 0.5872
# Epoch 11: auc did not improve from 0.58758
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5093 - auc: 0.5874 - val_loss: 0.5121 - val_auc: 0.5926 - lr: 0.0010
# Epoch 12/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5098 - auc: 0.5870
# Epoch 12: auc did not improve from 0.58758
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5094 - auc: 0.5865 - val_loss: 0.5145 - val_auc: 0.5930 - lr: 0.0010
# Epoch 13/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5099 - auc: 0.5861
# Epoch 13: auc did not improve from 0.58758
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5097 - auc: 0.5860 - val_loss: 0.5237 - val_auc: 0.5893 - lr: 0.0010
# Epoch 14/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5097 - auc: 0.5846
# Epoch 14: auc did not improve from 0.58758
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5097 - auc: 0.5846 - val_loss: 0.5108 - val_auc: 0.5910 - lr: 0.0010
# Epoch 15/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5086 - auc: 0.5886
# Epoch 15: auc improved from 0.58758 to 0.58803, saving model to best.h5
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5091 - auc: 0.5880 - val_loss: 0.5148 - val_auc: 0.5932 - lr: 9.0000e-04
# Epoch 16/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5094 - auc: 0.5874
# Epoch 16: auc did not improve from 0.58803
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5098 - auc: 0.5859 - val_loss: 0.5118 - val_auc: 0.5926 - lr: 9.0000e-04
# Epoch 17/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5094 - auc: 0.5861
# Epoch 17: auc did not improve from 0.58803
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5094 - auc: 0.5861 - val_loss: 0.5099 - val_auc: 0.5936 - lr: 9.0000e-04
# Epoch 18/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5094 - auc: 0.5858
# Epoch 18: auc did not improve from 0.58803
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5094 - auc: 0.5858 - val_loss: 0.5127 - val_auc: 0.5921 - lr: 9.0000e-04
# Epoch 19/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5092 - auc: 0.5863
# Epoch 19: auc did not improve from 0.58803
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5092 - auc: 0.5864 - val_loss: 0.5111 - val_auc: 0.5924 - lr: 9.0000e-04
# Epoch 20/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5100 - auc: 0.5840
# Epoch 20: auc did not improve from 0.58803
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5094 - auc: 0.5847 - val_loss: 0.5129 - val_auc: 0.5922 - lr: 9.0000e-04
# Epoch 21/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5095 - auc: 0.5868
# Epoch 21: auc did not improve from 0.58803
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5095 - auc: 0.5869 - val_loss: 0.5127 - val_auc: 0.5928 - lr: 8.1000e-04
# Epoch 22/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5105 - auc: 0.5850
# Epoch 22: auc did not improve from 0.58803
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5099 - auc: 0.5850 - val_loss: 0.5145 - val_auc: 0.5905 - lr: 8.1000e-04
# Epoch 23/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5091 - auc: 0.5861
# Epoch 23: auc did not improve from 0.58803
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5095 - auc: 0.5861 - val_loss: 0.5122 - val_auc: 0.5886 - lr: 8.1000e-04
# Epoch 24/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5089 - auc: 0.5875
# Epoch 24: auc did not improve from 0.58803
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5093 - auc: 0.5876 - val_loss: 0.5112 - val_auc: 0.5925 - lr: 8.1000e-04
# Epoch 25/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5093 - auc: 0.5874
# Epoch 25: auc did not improve from 0.58803
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5094 - auc: 0.5874 - val_loss: 0.5690 - val_auc: 0.5945 - lr: 8.1000e-04
# Epoch 26/100
# 252/254 [============================>.] - ETA: 0s - loss: 0.5096 - auc: 0.5856
# Epoch 26: auc did not improve from 0.58803
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5098 - auc: 0.5866 - val_loss: 0.5148 - val_auc: 0.5926 - lr: 7.2900e-04
# Epoch 27/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5096 - auc: 0.5876
# Epoch 27: auc did not improve from 0.58803
# 254/254 [==============================] - 2s 10ms/step - loss: 0.5096 - auc: 0.5876 - val_loss: 0.5143 - val_auc: 0.5871 - lr: 7.2900e-04
#
# fold_2
#
# Epoch 1/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.6000 - auc: 0.5336
# Epoch 1: auc did not improve from 0.58803
# 246/246 [==============================] - 5s 11ms/step - loss: 0.6000 - auc: 0.5332 - val_loss: 0.5629 - val_auc: 0.4769 - lr: 0.0010
# Epoch 2/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5177 - auc: 0.5727
# Epoch 2: auc did not improve from 0.58803
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5178 - auc: 0.5735 - val_loss: 0.5342 - val_auc: 0.5409 - lr: 0.0010
# Epoch 3/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5083 - auc: 0.5831
# Epoch 3: auc did not improve from 0.58803
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5083 - auc: 0.5831 - val_loss: 0.5274 - val_auc: 0.5381 - lr: 0.0010
# Epoch 4/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5070 - auc: 0.5825
# Epoch 4: auc did not improve from 0.58803
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5070 - auc: 0.5825 - val_loss: 0.5207 - val_auc: 0.5863 - lr: 0.0010
# Epoch 5/100
# 241/246 [============================>.] - ETA: 0s - loss: 0.5055 - auc: 0.5870
# Epoch 5: auc did not improve from 0.58803
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5058 - auc: 0.5873 - val_loss: 0.5228 - val_auc: 0.5705 - lr: 0.0010
# Epoch 6/100
# 240/246 [============================>.] - ETA: 0s - loss: 0.5061 - auc: 0.5842
# Epoch 6: auc did not improve from 0.58803
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5058 - auc: 0.5844 - val_loss: 0.5215 - val_auc: 0.5814 - lr: 0.0010
# Epoch 7/100
# 240/246 [============================>.] - ETA: 0s - loss: 0.5062 - auc: 0.5841
# Epoch 7: auc did not improve from 0.58803
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5055 - auc: 0.5846 - val_loss: 0.5199 - val_auc: 0.5822 - lr: 0.0010
# Epoch 8/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5033 - auc: 0.5885
# Epoch 8: auc improved from 0.58803 to 0.58847, saving model to best.h5
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5047 - auc: 0.5885 - val_loss: 0.5209 - val_auc: 0.5866 - lr: 0.0010
# Epoch 9/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5046 - auc: 0.5871
# Epoch 9: auc did not improve from 0.58847
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5048 - auc: 0.5878 - val_loss: 0.5190 - val_auc: 0.5855 - lr: 0.0010
# Epoch 10/100
# 244/246 [============================>.] - ETA: 0s - loss: 0.5045 - auc: 0.5877
# Epoch 10: auc did not improve from 0.58847
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5050 - auc: 0.5872 - val_loss: 0.5184 - val_auc: 0.5883 - lr: 0.0010
# Epoch 11/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5047 - auc: 0.5901
# Epoch 11: auc improved from 0.58847 to 0.58982, saving model to best.h5
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5044 - auc: 0.5898 - val_loss: 0.5180 - val_auc: 0.5855 - lr: 0.0010
# Epoch 12/100
# 244/246 [============================>.] - ETA: 0s - loss: 0.5044 - auc: 0.5872
# Epoch 12: auc did not improve from 0.58982
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5046 - auc: 0.5869 - val_loss: 0.5187 - val_auc: 0.5867 - lr: 0.0010
# Epoch 13/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5044 - auc: 0.5887
# Epoch 13: auc did not improve from 0.58982
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5044 - auc: 0.5885 - val_loss: 0.5721 - val_auc: 0.5879 - lr: 0.0010
# Epoch 14/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5045 - auc: 0.5880
# Epoch 14: auc did not improve from 0.58982
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5045 - auc: 0.5876 - val_loss: 0.5189 - val_auc: 0.5878 - lr: 0.0010
# Epoch 15/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5043 - auc: 0.5893
# Epoch 15: auc did not improve from 0.58982
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5043 - auc: 0.5893 - val_loss: 0.5172 - val_auc: 0.5888 - lr: 0.0010
# Epoch 16/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5042 - auc: 0.5895
# Epoch 16: auc did not improve from 0.58982
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5042 - auc: 0.5895 - val_loss: 0.5209 - val_auc: 0.5845 - lr: 0.0010
# Epoch 17/100
# 244/246 [============================>.] - ETA: 0s - loss: 0.5047 - auc: 0.5889
# Epoch 17: auc did not improve from 0.58982
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5041 - auc: 0.5897 - val_loss: 0.5190 - val_auc: 0.5889 - lr: 9.0000e-04
# Epoch 18/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5045 - auc: 0.5879
# Epoch 18: auc did not improve from 0.58982
# 246/246 [==============================] - 4s 15ms/step - loss: 0.5042 - auc: 0.5878 - val_loss: 0.5189 - val_auc: 0.5886 - lr: 9.0000e-04
# Epoch 19/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5043 - auc: 0.5888
# Epoch 19: auc did not improve from 0.58982
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5043 - auc: 0.5888 - val_loss: 0.5185 - val_auc: 0.5837 - lr: 9.0000e-04
# Epoch 20/100
# 241/246 [============================>.] - ETA: 0s - loss: 0.5035 - auc: 0.5882
# Epoch 20: auc did not improve from 0.58982
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5044 - auc: 0.5889 - val_loss: 0.5176 - val_auc: 0.5900 - lr: 9.0000e-04
# Epoch 21/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5037 - auc: 0.5895
# Epoch 21: auc did not improve from 0.58982
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5039 - auc: 0.5894 - val_loss: 0.5249 - val_auc: 0.5890 - lr: 9.0000e-04
# Epoch 22/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5044 - auc: 0.5900
# Epoch 22: auc improved from 0.58982 to 0.59011, saving model to best.h5
# 246/246 [==============================] - 3s 10ms/step - loss: 0.5044 - auc: 0.5901 - val_loss: 0.5182 - val_auc: 0.5877 - lr: 8.1000e-04
# Epoch 23/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5043 - auc: 0.5893
# Epoch 23: auc did not improve from 0.59011
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5043 - auc: 0.5896 - val_loss: 0.5182 - val_auc: 0.5886 - lr: 8.1000e-04
# Epoch 24/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5046 - auc: 0.5889
# Epoch 24: auc did not improve from 0.59011
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5045 - auc: 0.5888 - val_loss: 0.5182 - val_auc: 0.5879 - lr: 8.1000e-04
# Epoch 25/100
# 244/246 [============================>.] - ETA: 0s - loss: 0.5044 - auc: 0.5898
# Epoch 25: auc did not improve from 0.59011
# 246/246 [==============================] - 2s 10ms/step - loss: 0.5042 - auc: 0.5897 - val_loss: 0.5179 - val_auc: 0.5873 - lr: 8.1000e-04
#
# fold_3
#
# Epoch 1/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5956 - auc: 0.5393
# Epoch 1: auc did not improve from 0.59011
# 256/256 [==============================] - 5s 12ms/step - loss: 0.5956 - auc: 0.5393 - val_loss: 0.5310 - val_auc: 0.5830 - lr: 0.0010
# Epoch 2/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5137 - auc: 0.5722
# Epoch 2: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5137 - auc: 0.5722 - val_loss: 0.5265 - val_auc: 0.5781 - lr: 0.0010
# Epoch 3/100
# 250/256 [============================>.] - ETA: 0s - loss: 0.5070 - auc: 0.5746
# Epoch 3: auc did not improve from 0.59011
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5070 - auc: 0.5752 - val_loss: 0.5276 - val_auc: 0.5699 - lr: 0.0010
# Epoch 4/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5058 - auc: 0.5766
# Epoch 4: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5058 - auc: 0.5766 - val_loss: 0.5254 - val_auc: 0.5865 - lr: 0.0010
# Epoch 5/100
# 250/256 [============================>.] - ETA: 0s - loss: 0.5043 - auc: 0.5803
# Epoch 5: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5045 - auc: 0.5811 - val_loss: 0.5245 - val_auc: 0.5905 - lr: 0.0010
# Epoch 6/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5041 - auc: 0.5800
# Epoch 6: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5041 - auc: 0.5800 - val_loss: 0.5240 - val_auc: 0.5941 - lr: 0.0010
# Epoch 7/100
# 250/256 [============================>.] - ETA: 0s - loss: 0.5052 - auc: 0.5805
# Epoch 7: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5042 - auc: 0.5807 - val_loss: 0.5219 - val_auc: 0.5951 - lr: 0.0010
# Epoch 8/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5027 - auc: 0.5844
# Epoch 8: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5028 - auc: 0.5840 - val_loss: 0.5244 - val_auc: 0.5954 - lr: 0.0010
# Epoch 9/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5042 - auc: 0.5840
# Epoch 9: auc did not improve from 0.59011
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5032 - auc: 0.5833 - val_loss: 0.5225 - val_auc: 0.5945 - lr: 0.0010
# Epoch 10/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5028 - auc: 0.5842
# Epoch 10: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5028 - auc: 0.5842 - val_loss: 0.5239 - val_auc: 0.5944 - lr: 0.0010
# Epoch 11/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5024 - auc: 0.5849
# Epoch 11: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5029 - auc: 0.5841 - val_loss: 0.5260 - val_auc: 0.5937 - lr: 0.0010
# Epoch 12/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.5027 - auc: 0.5833
# Epoch 12: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5029 - auc: 0.5835 - val_loss: 0.5205 - val_auc: 0.5942 - lr: 0.0010
# Epoch 13/100
# 252/256 [============================>.] - ETA: 0s - loss: 0.5030 - auc: 0.5827
# Epoch 13: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5031 - auc: 0.5839 - val_loss: 0.5235 - val_auc: 0.5941 - lr: 0.0010
# Epoch 14/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5031 - auc: 0.5821
# Epoch 14: auc did not improve from 0.59011
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5028 - auc: 0.5829 - val_loss: 0.5232 - val_auc: 0.5955 - lr: 0.0010
# Epoch 15/100
# 251/256 [============================>.] - ETA: 0s - loss: 0.5037 - auc: 0.5833
# Epoch 15: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5027 - auc: 0.5838 - val_loss: 0.5248 - val_auc: 0.5950 - lr: 0.0010
# Epoch 16/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5030 - auc: 0.5838
# Epoch 16: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5030 - auc: 0.5838 - val_loss: 0.5271 - val_auc: 0.5937 - lr: 9.0000e-04
# Epoch 17/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5024 - auc: 0.5850
# Epoch 17: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5027 - auc: 0.5846 - val_loss: 0.5268 - val_auc: 0.5946 - lr: 9.0000e-04
# Epoch 18/100
# 256/256 [==============================] - ETA: 0s - loss: 0.5027 - auc: 0.5849
# Epoch 18: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5027 - auc: 0.5849 - val_loss: 0.5252 - val_auc: 0.5947 - lr: 9.0000e-04
# Epoch 19/100
# 250/256 [============================>.] - ETA: 0s - loss: 0.5019 - auc: 0.5827
# Epoch 19: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5028 - auc: 0.5819 - val_loss: 0.5255 - val_auc: 0.5939 - lr: 9.0000e-04
# Epoch 20/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.5029 - auc: 0.5846
# Epoch 20: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5028 - auc: 0.5845 - val_loss: 0.5299 - val_auc: 0.5929 - lr: 9.0000e-04
# Epoch 21/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.5024 - auc: 0.5849
# Epoch 21: auc did not improve from 0.59011
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5022 - auc: 0.5850 - val_loss: 0.5289 - val_auc: 0.5904 - lr: 9.0000e-04
# Epoch 22/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.5026 - auc: 0.5833
# Epoch 22: auc did not improve from 0.59011
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5027 - auc: 0.5833 - val_loss: 0.5390 - val_auc: 0.5457 - lr: 9.0000e-04
#
# fold_4
#
# Epoch 1/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.6069 - auc: 0.5378
# Epoch 1: auc did not improve from 0.59011
# 252/252 [==============================] - 5s 12ms/step - loss: 0.6063 - auc: 0.5362 - val_loss: 0.5380 - val_auc: 0.5146 - lr: 0.0010
# Epoch 2/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5207 - auc: 0.5698
# Epoch 2: auc did not improve from 0.59011
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5205 - auc: 0.5699 - val_loss: 0.5254 - val_auc: 0.5597 - lr: 0.0010
# Epoch 3/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5103 - auc: 0.5795
# Epoch 3: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5101 - auc: 0.5800 - val_loss: 0.5213 - val_auc: 0.5752 - lr: 0.0010
# Epoch 4/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5095 - auc: 0.5780
# Epoch 4: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 13ms/step - loss: 0.5093 - auc: 0.5786 - val_loss: 0.5208 - val_auc: 0.5720 - lr: 0.0010
# Epoch 5/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5080 - auc: 0.5808
# Epoch 5: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5084 - auc: 0.5815 - val_loss: 0.5181 - val_auc: 0.5804 - lr: 0.0010
# Epoch 6/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5070 - auc: 0.5869
# Epoch 6: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5074 - auc: 0.5866 - val_loss: 0.5184 - val_auc: 0.5819 - lr: 0.0010
# Epoch 7/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5076 - auc: 0.5860
# Epoch 7: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5073 - auc: 0.5861 - val_loss: 0.5172 - val_auc: 0.5853 - lr: 0.0010
# Epoch 8/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5073 - auc: 0.5867
# Epoch 8: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5070 - auc: 0.5875 - val_loss: 0.5177 - val_auc: 0.5888 - lr: 0.0010
# Epoch 9/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5072 - auc: 0.5882
# Epoch 9: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5069 - auc: 0.5878 - val_loss: 0.5173 - val_auc: 0.5880 - lr: 0.0010
# Epoch 10/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5060 - auc: 0.5895
# Epoch 10: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5064 - auc: 0.5900 - val_loss: 0.5160 - val_auc: 0.5898 - lr: 0.0010
# Epoch 11/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5066 - auc: 0.5896
# Epoch 11: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5063 - auc: 0.5899 - val_loss: 0.5172 - val_auc: 0.5889 - lr: 0.0010
# Epoch 12/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5074 - auc: 0.5865
# Epoch 12: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5068 - auc: 0.5870 - val_loss: 0.5263 - val_auc: 0.5866 - lr: 0.0010
# Epoch 13/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5057 - auc: 0.5893
# Epoch 13: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5062 - auc: 0.5885 - val_loss: 0.5163 - val_auc: 0.5892 - lr: 0.0010
# Epoch 14/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5065 - auc: 0.5868
# Epoch 14: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5065 - auc: 0.5880 - val_loss: 0.5183 - val_auc: 0.5886 - lr: 0.0010
# Epoch 15/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5067 - auc: 0.5901
# Epoch 15: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5061 - auc: 0.5897 - val_loss: 0.5194 - val_auc: 0.5802 - lr: 0.0010
# Epoch 16/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5063 - auc: 0.5879
# Epoch 16: auc did not improve from 0.59011
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5065 - auc: 0.5879 - val_loss: 0.5174 - val_auc: 0.5894 - lr: 9.0000e-04
# Epoch 17/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5063 - auc: 0.5919
# Epoch 17: auc improved from 0.59011 to 0.59058, saving model to best.h5
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5061 - auc: 0.5906 - val_loss: 0.5164 - val_auc: 0.5861 - lr: 9.0000e-04
# Epoch 18/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5061 - auc: 0.5891
# Epoch 18: auc did not improve from 0.59058
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5061 - auc: 0.5891 - val_loss: 0.5155 - val_auc: 0.5883 - lr: 9.0000e-04
# Epoch 19/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5057 - auc: 0.5890
# Epoch 19: auc did not improve from 0.59058
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5060 - auc: 0.5891 - val_loss: 0.5228 - val_auc: 0.5850 - lr: 9.0000e-04
# Epoch 20/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5050 - auc: 0.5865
# Epoch 20: auc did not improve from 0.59058
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5067 - auc: 0.5869 - val_loss: 0.5222 - val_auc: 0.5713 - lr: 9.0000e-04
# Epoch 21/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5066 - auc: 0.5893
# Epoch 21: auc did not improve from 0.59058
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5066 - auc: 0.5881 - val_loss: 0.5338 - val_auc: 0.5871 - lr: 9.0000e-04
# Epoch 22/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5061 - auc: 0.5883
# Epoch 22: auc did not improve from 0.59058
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5061 - auc: 0.5893 - val_loss: 0.5242 - val_auc: 0.5898 - lr: 9.0000e-04
# Epoch 23/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5063 - auc: 0.5874
# Epoch 23: auc did not improve from 0.59058
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5064 - auc: 0.5884 - val_loss: 0.5353 - val_auc: 0.5160 - lr: 8.1000e-04
# Epoch 24/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5067 - auc: 0.5893
# Epoch 24: auc did not improve from 0.59058
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5065 - auc: 0.5889 - val_loss: 0.5257 - val_auc: 0.5883 - lr: 8.1000e-04
# Epoch 25/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5062 - auc: 0.5894
# Epoch 25: auc did not improve from 0.59058
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5066 - auc: 0.5886 - val_loss: 0.5151 - val_auc: 0.5888 - lr: 8.1000e-04
# Epoch 26/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5064 - auc: 0.5891
# Epoch 26: auc did not improve from 0.59058
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5062 - auc: 0.5889 - val_loss: 0.5374 - val_auc: 0.5279 - lr: 8.1000e-04
# Epoch 27/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5064 - auc: 0.5894
# Epoch 27: auc did not improve from 0.59058
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5063 - auc: 0.5901 - val_loss: 0.5198 - val_auc: 0.5890 - lr: 8.1000e-04
# Epoch 28/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5060 - auc: 0.5917
# Epoch 28: auc improved from 0.59058 to 0.59227, saving model to best.h5
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5061 - auc: 0.5923 - val_loss: 0.5361 - val_auc: 0.5020 - lr: 7.2900e-04
# Epoch 29/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5074 - auc: 0.5891
# Epoch 29: auc did not improve from 0.59227
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5065 - auc: 0.5890 - val_loss: 0.5225 - val_auc: 0.5856 - lr: 7.2900e-04
# Epoch 30/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5060 - auc: 0.5892
# Epoch 30: auc did not improve from 0.59227
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5063 - auc: 0.5899 - val_loss: 0.5186 - val_auc: 0.5864 - lr: 7.2900e-04
# Epoch 31/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5066 - auc: 0.5885
# Epoch 31: auc did not improve from 0.59227
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5066 - auc: 0.5889 - val_loss: 0.5189 - val_auc: 0.5883 - lr: 7.2900e-04
# Epoch 32/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5074 - auc: 0.5896
# Epoch 32: auc did not improve from 0.59227
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5067 - auc: 0.5899 - val_loss: 0.5201 - val_auc: 0.5824 - lr: 7.2900e-04
# Epoch 33/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5079 - auc: 0.5888
# Epoch 33: auc did not improve from 0.59227
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5065 - auc: 0.5892 - val_loss: 0.5175 - val_auc: 0.5848 - lr: 7.2900e-04
# Epoch 34/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5062 - auc: 0.5898
# Epoch 34: auc did not improve from 0.59227
# 252/252 [==============================] - 3s 10ms/step - loss: 0.5064 - auc: 0.5895 - val_loss: 0.5198 - val_auc: 0.5858 - lr: 6.5610e-04
# Epoch 35/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5062 - auc: 0.5914
# Epoch 35: auc did not improve from 0.59227
# 252/252 [==============================] - 2s 10ms/step - loss: 0.5066 - auc: 0.5910 - val_loss: 0.5179 - val_auc: 0.5889 - lr: 6.5610e-04
#
# fold_5
#
# Epoch 1/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.6019 - auc: 0.5423
# Epoch 1: auc did not improve from 0.59227
# 244/244 [==============================] - 5s 13ms/step - loss: 0.6014 - auc: 0.5426 - val_loss: 0.5515 - val_auc: 0.5233 - lr: 0.0010
# Epoch 2/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.5275 - auc: 0.5740
# Epoch 2: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5275 - auc: 0.5740 - val_loss: 0.5117 - val_auc: 0.5636 - lr: 0.0010
# Epoch 3/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.5209 - auc: 0.5767
# Epoch 3: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5210 - auc: 0.5766 - val_loss: 0.5126 - val_auc: 0.5435 - lr: 0.0010
# Epoch 4/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.5196 - auc: 0.5776
# Epoch 4: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5196 - auc: 0.5776 - val_loss: 0.5085 - val_auc: 0.5668 - lr: 0.0010
# Epoch 5/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.5177 - auc: 0.5869
# Epoch 5: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5177 - auc: 0.5858 - val_loss: 0.5058 - val_auc: 0.5783 - lr: 0.0010
# Epoch 6/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.5165 - auc: 0.5882
# Epoch 6: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5163 - auc: 0.5876 - val_loss: 0.5090 - val_auc: 0.5692 - lr: 0.0010
# Epoch 7/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.5169 - auc: 0.5855
# Epoch 7: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5166 - auc: 0.5859 - val_loss: 0.5084 - val_auc: 0.5846 - lr: 0.0010
# Epoch 8/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.5174 - auc: 0.5847
# Epoch 8: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5164 - auc: 0.5848 - val_loss: 0.5042 - val_auc: 0.5870 - lr: 0.0010
# Epoch 9/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.5160 - auc: 0.5869
# Epoch 9: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5163 - auc: 0.5865 - val_loss: 0.5044 - val_auc: 0.5903 - lr: 0.0010
# Epoch 10/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5166 - auc: 0.5861
# Epoch 10: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 10ms/step - loss: 0.5168 - auc: 0.5869 - val_loss: 0.5037 - val_auc: 0.5882 - lr: 0.0010
# Epoch 11/100
# 244/244 [==============================] - ETA: 0s - loss: 0.5162 - auc: 0.5888
# Epoch 11: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5162 - auc: 0.5888 - val_loss: 0.5023 - val_auc: 0.5893 - lr: 0.0010
# Epoch 12/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5154 - auc: 0.5891
# Epoch 12: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 10ms/step - loss: 0.5159 - auc: 0.5887 - val_loss: 0.5018 - val_auc: 0.5878 - lr: 0.0010
# Epoch 13/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.5157 - auc: 0.5879
# Epoch 13: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5157 - auc: 0.5879 - val_loss: 0.5022 - val_auc: 0.5878 - lr: 0.0010
# Epoch 14/100
# 244/244 [==============================] - ETA: 0s - loss: 0.5157 - auc: 0.5884
# Epoch 14: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5157 - auc: 0.5884 - val_loss: 0.5012 - val_auc: 0.5883 - lr: 0.0010
# Epoch 15/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.5158 - auc: 0.5871
# Epoch 15: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5158 - auc: 0.5876 - val_loss: 0.5019 - val_auc: 0.5884 - lr: 0.0010
# Epoch 16/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.5155 - auc: 0.5883
# Epoch 16: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5156 - auc: 0.5885 - val_loss: 0.5029 - val_auc: 0.5883 - lr: 0.0010
# Epoch 17/100
# 238/244 [============================>.] - ETA: 0s - loss: 0.5149 - auc: 0.5899
# Epoch 17: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5156 - auc: 0.5895 - val_loss: 0.5045 - val_auc: 0.5887 - lr: 9.0000e-04
# Epoch 18/100
# 244/244 [==============================] - ETA: 0s - loss: 0.5164 - auc: 0.5864
# Epoch 18: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5164 - auc: 0.5864 - val_loss: 0.5071 - val_auc: 0.5867 - lr: 9.0000e-04
# Epoch 19/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5151 - auc: 0.5914
# Epoch 19: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5153 - auc: 0.5905 - val_loss: 0.5061 - val_auc: 0.5869 - lr: 9.0000e-04
# Epoch 20/100
# 238/244 [============================>.] - ETA: 0s - loss: 0.5148 - auc: 0.5883
# Epoch 20: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5161 - auc: 0.5882 - val_loss: 0.5041 - val_auc: 0.5888 - lr: 9.0000e-04
# Epoch 21/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5153 - auc: 0.5890
# Epoch 21: auc did not improve from 0.59227
# 244/244 [==============================] - 2s 10ms/step - loss: 0.5156 - auc: 0.5893 - val_loss: 0.5022 - val_auc: 0.5878 - lr: 9.0000e-04
# Epoch 22/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.5154 - auc: 0.5887
# Epoch 22: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5154 - auc: 0.5887 - val_loss: 0.5042 - val_auc: 0.5884 - lr: 9.0000e-04
# Epoch 23/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.5151 - auc: 0.5910
# Epoch 23: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5153 - auc: 0.5909 - val_loss: 0.5026 - val_auc: 0.5869 - lr: 9.0000e-04
# Epoch 24/100
# 244/244 [==============================] - ETA: 0s - loss: 0.5164 - auc: 0.5866
# Epoch 24: auc did not improve from 0.59227
# 244/244 [==============================] - 3s 11ms/step - loss: 0.5164 - auc: 0.5866 - val_loss: 0.5037 - val_auc: 0.5871 - lr: 9.0000e-04
#
# fold_6
#
# Epoch 1/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.6060 - auc: 0.5460
# Epoch 1: auc did not improve from 0.59227
# 254/254 [==============================] - 5s 12ms/step - loss: 0.6058 - auc: 0.5446 - val_loss: 0.5672 - val_auc: 0.5534 - lr: 0.0010
# Epoch 2/100
# 252/254 [============================>.] - ETA: 0s - loss: 0.5270 - auc: 0.5676
# Epoch 2: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5271 - auc: 0.5675 - val_loss: 0.5211 - val_auc: 0.5600 - lr: 0.0010
# Epoch 3/100
# 248/254 [============================>.] - ETA: 0s - loss: 0.5172 - auc: 0.5789
# Epoch 3: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5172 - auc: 0.5794 - val_loss: 0.5096 - val_auc: 0.5812 - lr: 0.0010
# Epoch 4/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5153 - auc: 0.5820
# Epoch 4: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5155 - auc: 0.5819 - val_loss: 0.5103 - val_auc: 0.5889 - lr: 0.0010
# Epoch 5/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5150 - auc: 0.5832
# Epoch 5: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5148 - auc: 0.5823 - val_loss: 0.5100 - val_auc: 0.5840 - lr: 0.0010
# Epoch 6/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5145 - auc: 0.5827
# Epoch 6: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5145 - auc: 0.5826 - val_loss: 0.5090 - val_auc: 0.5796 - lr: 0.0010
# Epoch 7/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5136 - auc: 0.5815
# Epoch 7: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5141 - auc: 0.5819 - val_loss: 0.5069 - val_auc: 0.5899 - lr: 0.0010
# Epoch 8/100
# 250/254 [============================>.] - ETA: 0s - loss: 0.5140 - auc: 0.5852
# Epoch 8: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5141 - auc: 0.5852 - val_loss: 0.5115 - val_auc: 0.5935 - lr: 0.0010
# Epoch 9/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5139 - auc: 0.5840
# Epoch 9: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5141 - auc: 0.5835 - val_loss: 0.5049 - val_auc: 0.5929 - lr: 0.0010
# Epoch 10/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5142 - auc: 0.5852
# Epoch 10: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5137 - auc: 0.5856 - val_loss: 0.5086 - val_auc: 0.5900 - lr: 0.0010
# Epoch 11/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5130 - auc: 0.5847
# Epoch 11: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5135 - auc: 0.5851 - val_loss: 0.5042 - val_auc: 0.5909 - lr: 0.0010
# Epoch 12/100
# 252/254 [============================>.] - ETA: 0s - loss: 0.5134 - auc: 0.5855
# Epoch 12: auc did not improve from 0.59227
# 254/254 [==============================] - 4s 14ms/step - loss: 0.5134 - auc: 0.5853 - val_loss: 0.5045 - val_auc: 0.5909 - lr: 0.0010
# Epoch 13/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5137 - auc: 0.5831
# Epoch 13: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 13ms/step - loss: 0.5137 - auc: 0.5835 - val_loss: 0.5037 - val_auc: 0.5944 - lr: 0.0010
# Epoch 14/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5129 - auc: 0.5850
# Epoch 14: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5133 - auc: 0.5856 - val_loss: 0.5201 - val_auc: 0.5921 - lr: 0.0010
# Epoch 15/100
# 252/254 [============================>.] - ETA: 0s - loss: 0.5136 - auc: 0.5844
# Epoch 15: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5137 - auc: 0.5840 - val_loss: 0.5054 - val_auc: 0.5915 - lr: 0.0010
# Epoch 16/100
# 253/254 [============================>.] - ETA: 0s - loss: 0.5129 - auc: 0.5867
# Epoch 16: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5131 - auc: 0.5864 - val_loss: 0.5068 - val_auc: 0.5918 - lr: 9.0000e-04
# Epoch 17/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5129 - auc: 0.5852
# Epoch 17: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5136 - auc: 0.5841 - val_loss: 0.5070 - val_auc: 0.5932 - lr: 9.0000e-04
# Epoch 18/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5138 - auc: 0.5853
# Epoch 18: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5139 - auc: 0.5847 - val_loss: 0.5082 - val_auc: 0.5921 - lr: 9.0000e-04
# Epoch 19/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5133 - auc: 0.5850
# Epoch 19: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5132 - auc: 0.5845 - val_loss: 0.5077 - val_auc: 0.5926 - lr: 9.0000e-04
# Epoch 20/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5135 - auc: 0.5859
# Epoch 20: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5135 - auc: 0.5859 - val_loss: 0.5040 - val_auc: 0.5921 - lr: 9.0000e-04
# Epoch 21/100
# 251/254 [============================>.] - ETA: 0s - loss: 0.5136 - auc: 0.5869
# Epoch 21: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5131 - auc: 0.5860 - val_loss: 0.5070 - val_auc: 0.5902 - lr: 9.0000e-04
# Epoch 22/100
# 249/254 [============================>.] - ETA: 0s - loss: 0.5139 - auc: 0.5843
# Epoch 22: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 10ms/step - loss: 0.5137 - auc: 0.5845 - val_loss: 0.5198 - val_auc: 0.5903 - lr: 8.1000e-04
# Epoch 23/100
# 254/254 [==============================] - ETA: 0s - loss: 0.5138 - auc: 0.5826
# Epoch 23: auc did not improve from 0.59227
# 254/254 [==============================] - 3s 11ms/step - loss: 0.5138 - auc: 0.5826 - val_loss: 0.5041 - val_auc: 0.5919 - lr: 8.1000e-04
#
# fold_7
#
# Epoch 1/100
# 246/250 [============================>.] - ETA: 0s - loss: 0.6133 - auc: 0.5458
# Epoch 1: auc did not improve from 0.59227
# 250/250 [==============================] - 5s 12ms/step - loss: 0.6123 - auc: 0.5460 - val_loss: 0.5365 - val_auc: 0.5774 - lr: 0.0010
# Epoch 2/100
# 245/250 [============================>.] - ETA: 0s - loss: 0.5313 - auc: 0.5734
# Epoch 2: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5310 - auc: 0.5729 - val_loss: 0.5052 - val_auc: 0.5751 - lr: 0.0010
# Epoch 3/100
# 245/250 [============================>.] - ETA: 0s - loss: 0.5214 - auc: 0.5780
# Epoch 3: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5216 - auc: 0.5765 - val_loss: 0.5074 - val_auc: 0.5740 - lr: 0.0010
# Epoch 4/100
# 246/250 [============================>.] - ETA: 0s - loss: 0.5200 - auc: 0.5819
# Epoch 4: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5202 - auc: 0.5816 - val_loss: 0.5048 - val_auc: 0.5744 - lr: 0.0010
# Epoch 5/100
# 247/250 [============================>.] - ETA: 0s - loss: 0.5193 - auc: 0.5846
# Epoch 5: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5185 - auc: 0.5844 - val_loss: 0.5062 - val_auc: 0.5623 - lr: 0.0010
# Epoch 6/100
# 245/250 [============================>.] - ETA: 0s - loss: 0.5182 - auc: 0.5835
# Epoch 6: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5180 - auc: 0.5837 - val_loss: 0.5069 - val_auc: 0.5732 - lr: 0.0010
# Epoch 7/100
# 247/250 [============================>.] - ETA: 0s - loss: 0.5185 - auc: 0.5886
# Epoch 7: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5181 - auc: 0.5879 - val_loss: 0.5028 - val_auc: 0.5814 - lr: 0.0010
# Epoch 8/100
# 246/250 [============================>.] - ETA: 0s - loss: 0.5178 - auc: 0.5871
# Epoch 8: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5175 - auc: 0.5868 - val_loss: 0.5008 - val_auc: 0.5854 - lr: 0.0010
# Epoch 9/100
# 249/250 [============================>.] - ETA: 0s - loss: 0.5179 - auc: 0.5863
# Epoch 9: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5180 - auc: 0.5861 - val_loss: 0.5032 - val_auc: 0.5839 - lr: 0.0010
# Epoch 10/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5175 - auc: 0.5901
# Epoch 10: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5175 - auc: 0.5901 - val_loss: 0.5067 - val_auc: 0.5858 - lr: 0.0010
# Epoch 11/100
# 245/250 [============================>.] - ETA: 0s - loss: 0.5177 - auc: 0.5860
# Epoch 11: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5178 - auc: 0.5872 - val_loss: 0.5007 - val_auc: 0.5871 - lr: 0.0010
# Epoch 12/100
# 246/250 [============================>.] - ETA: 0s - loss: 0.5174 - auc: 0.5874
# Epoch 12: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5173 - auc: 0.5877 - val_loss: 0.5296 - val_auc: 0.5876 - lr: 0.0010
# Epoch 13/100
# 247/250 [============================>.] - ETA: 0s - loss: 0.5188 - auc: 0.5859
# Epoch 13: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5177 - auc: 0.5867 - val_loss: 0.4988 - val_auc: 0.5858 - lr: 0.0010
# Epoch 14/100
# 246/250 [============================>.] - ETA: 0s - loss: 0.5174 - auc: 0.5888
# Epoch 14: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5173 - auc: 0.5884 - val_loss: 0.4990 - val_auc: 0.5868 - lr: 0.0010
# Epoch 15/100
# 244/250 [============================>.] - ETA: 0s - loss: 0.5169 - auc: 0.5884
# Epoch 15: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5175 - auc: 0.5877 - val_loss: 0.5147 - val_auc: 0.5864 - lr: 0.0010
# Epoch 16/100
# 249/250 [============================>.] - ETA: 0s - loss: 0.5173 - auc: 0.5881
# Epoch 16: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5175 - auc: 0.5886 - val_loss: 0.5004 - val_auc: 0.5862 - lr: 9.0000e-04
# Epoch 17/100
# 246/250 [============================>.] - ETA: 0s - loss: 0.5173 - auc: 0.5885
# Epoch 17: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5173 - auc: 0.5881 - val_loss: 0.5061 - val_auc: 0.5846 - lr: 9.0000e-04
# Epoch 18/100
# 249/250 [============================>.] - ETA: 0s - loss: 0.5174 - auc: 0.5890
# Epoch 18: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5174 - auc: 0.5890 - val_loss: 0.4993 - val_auc: 0.5861 - lr: 9.0000e-04
# Epoch 19/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5169 - auc: 0.5913
# Epoch 19: auc did not improve from 0.59227
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5169 - auc: 0.5913 - val_loss: 0.4985 - val_auc: 0.5847 - lr: 9.0000e-04
# Epoch 20/100
# ...
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5083 - auc: 0.5899 - val_loss: 0.5126 - val_auc: 0.5908 - lr: 0.0010
# Epoch 12/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5082 - auc: 0.5907
# Epoch 12: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5082 - auc: 0.5893 - val_loss: 0.5300 - val_auc: 0.5880 - lr: 0.0010
# Epoch 13/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5087 - auc: 0.5877
# Epoch 13: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5087 - auc: 0.5877 - val_loss: 0.5151 - val_auc: 0.5892 - lr: 0.0010
# Epoch 14/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5084 - auc: 0.5878
# Epoch 14: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5085 - auc: 0.5882 - val_loss: 0.5151 - val_auc: 0.5886 - lr: 0.0010
# Epoch 15/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5088 - auc: 0.5866
# Epoch 15: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5087 - auc: 0.5867 - val_loss: 0.5274 - val_auc: 0.5883 - lr: 0.0010
# Epoch 16/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5084 - auc: 0.5890
# Epoch 16: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5084 - auc: 0.5890 - val_loss: 0.5118 - val_auc: 0.5889 - lr: 0.0010
# Epoch 17/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5082 - auc: 0.5898
# Epoch 17: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5082 - auc: 0.5898 - val_loss: 0.5169 - val_auc: 0.5896 - lr: 9.0000e-04
# Epoch 18/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5087 - auc: 0.5879
# Epoch 18: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5086 - auc: 0.5880 - val_loss: 0.5217 - val_auc: 0.5883 - lr: 9.0000e-04
# Epoch 19/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5083 - auc: 0.5897
# Epoch 19: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5081 - auc: 0.5905 - val_loss: 0.5230 - val_auc: 0.5872 - lr: 9.0000e-04
# Epoch 20/100
# 244/246 [============================>.] - ETA: 0s - loss: 0.5083 - auc: 0.5881
# Epoch 20: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5084 - auc: 0.5880 - val_loss: 0.5145 - val_auc: 0.5870 - lr: 9.0000e-04
# Epoch 21/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5086 - auc: 0.5870
# Epoch 21: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5086 - auc: 0.5870 - val_loss: 0.5145 - val_auc: 0.5897 - lr: 9.0000e-04
# Epoch 22/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5090 - auc: 0.5866
# Epoch 22: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5090 - auc: 0.5864 - val_loss: 0.5137 - val_auc: 0.5880 - lr: 9.0000e-04
# Epoch 23/100
# 246/246 [==============================] - ETA: 0s - loss: 0.5084 - auc: 0.5885
# Epoch 23: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5084 - auc: 0.5885 - val_loss: 0.5170 - val_auc: 0.5888 - lr: 9.0000e-04
# Epoch 24/100
# 245/246 [============================>.] - ETA: 0s - loss: 0.5085 - auc: 0.5892
# Epoch 24: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5085 - auc: 0.5891 - val_loss: 0.5395 - val_auc: 0.5876 - lr: 9.0000e-04
# Epoch 25/100
# 242/246 [============================>.] - ETA: 0s - loss: 0.5090 - auc: 0.5877
# Epoch 25: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5089 - auc: 0.5881 - val_loss: 0.5160 - val_auc: 0.5884 - lr: 8.1000e-04
# Epoch 26/100
# 243/246 [============================>.] - ETA: 0s - loss: 0.5089 - auc: 0.5861
# Epoch 26: auc did not improve from 0.59227
# 246/246 [==============================] - 3s 11ms/step - loss: 0.5088 - auc: 0.5872 - val_loss: 0.5133 - val_auc: 0.5884 - lr: 8.1000e-04
#
# fold_9
#
# Epoch 1/100
# 242/242 [==============================] - ETA: 0s - loss: 0.6045 - auc: 0.5350
# Epoch 1: auc did not improve from 0.59227
# 242/242 [==============================] - 5s 13ms/step - loss: 0.6045 - auc: 0.5350 - val_loss: 0.5442 - val_auc: 0.4888 - lr: 0.0010
# Epoch 2/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5284 - auc: 0.5641
# Epoch 2: auc did not improve from 0.59227
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5283 - auc: 0.5648 - val_loss: 0.5219 - val_auc: 0.5663 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5180 - auc: 0.5847
# Epoch 3: auc did not improve from 0.59227
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5180 - auc: 0.5849 - val_loss: 0.5114 - val_auc: 0.5765 - lr: 0.0010
# Epoch 4/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5149 - auc: 0.5883
# Epoch 4: auc did not improve from 0.59227
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5152 - auc: 0.5877 - val_loss: 0.5133 - val_auc: 0.5793 - lr: 0.0010
# Epoch 5/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5144 - auc: 0.5892
# Epoch 5: auc did not improve from 0.59227
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5144 - auc: 0.5892 - val_loss: 0.5089 - val_auc: 0.5820 - lr: 0.0010
# Epoch 6/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5135 - auc: 0.5889
# Epoch 6: auc did not improve from 0.59227
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5135 - auc: 0.5889 - val_loss: 0.5112 - val_auc: 0.5858 - lr: 0.0010
# Epoch 7/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5137 - auc: 0.5895
# Epoch 7: auc did not improve from 0.59227
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5137 - auc: 0.5895 - val_loss: 0.5092 - val_auc: 0.5838 - lr: 0.0010
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5127 - auc: 0.5905
# Epoch 8: auc did not improve from 0.59227
# 242/242 [==============================] - 3s 12ms/step - loss: 0.5131 - auc: 0.5902 - val_loss: 0.5073 - val_auc: 0.5850 - lr: 0.0010
# Epoch 9/100
# 238/242 [============================>.] - ETA: 0s - loss: 0.5125 - auc: 0.5925
# Epoch 9: auc did not improve from 0.59227
# 242/242 [==============================] - 3s 12ms/step - loss: 0.5125 - auc: 0.5922 - val_loss: 0.5145 - val_auc: 0.5847 - lr: 0.0010
# Epoch 10/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5129 - auc: 0.5919
# Epoch 10: auc improved from 0.59227 to 0.59228, saving model to best.h5
# 242/242 [==============================] - 3s 12ms/step - loss: 0.5126 - auc: 0.5923 - val_loss: 0.5074 - val_auc: 0.5844 - lr: 0.0010
# Epoch 11/100
# 240/242 [============================>.] - ETA: 0s - loss: 0.5122 - auc: 0.5926
# Epoch 11: auc did not improve from 0.59228
# 242/242 [==============================] - 4s 17ms/step - loss: 0.5125 - auc: 0.5923 - val_loss: 0.5090 - val_auc: 0.5853 - lr: 0.0010
# Epoch 12/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5126 - auc: 0.5920
# Epoch 12: auc did not improve from 0.59228
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5125 - auc: 0.5920 - val_loss: 0.5073 - val_auc: 0.5843 - lr: 0.0010
# Epoch 13/100
# 238/242 [============================>.] - ETA: 0s - loss: 0.5130 - auc: 0.5905
# Epoch 13: auc did not improve from 0.59228
# 242/242 [==============================] - 3s 12ms/step - loss: 0.5127 - auc: 0.5914 - val_loss: 0.5057 - val_auc: 0.5848 - lr: 0.0010
# Epoch 14/100
# 240/242 [============================>.] - ETA: 0s - loss: 0.5123 - auc: 0.5928
# Epoch 14: auc improved from 0.59228 to 0.59244, saving model to best.h5
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5121 - auc: 0.5924 - val_loss: 0.5065 - val_auc: 0.5846 - lr: 0.0010
# Epoch 15/100
# 240/242 [============================>.] - ETA: 0s - loss: 0.5118 - auc: 0.5930
# Epoch 15: auc improved from 0.59244 to 0.59296, saving model to best.h5
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5120 - auc: 0.5930 - val_loss: 0.5114 - val_auc: 0.5819 - lr: 0.0010
# Epoch 16/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5128 - auc: 0.5898
# Epoch 16: auc did not improve from 0.59296
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5126 - auc: 0.5899 - val_loss: 0.5090 - val_auc: 0.5847 - lr: 0.0010
# Epoch 17/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5133 - auc: 0.5912
# Epoch 17: auc did not improve from 0.59296
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5123 - auc: 0.5923 - val_loss: 0.5060 - val_auc: 0.5841 - lr: 0.0010
# Epoch 18/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5120 - auc: 0.5954
# Epoch 18: auc improved from 0.59296 to 0.59496, saving model to best.h5
# 242/242 [==============================] - 3s 12ms/step - loss: 0.5118 - auc: 0.5950 - val_loss: 0.5070 - val_auc: 0.5841 - lr: 0.0010
# Epoch 19/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5118 - auc: 0.5933
# Epoch 19: auc did not improve from 0.59496
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5118 - auc: 0.5933 - val_loss: 0.5079 - val_auc: 0.5838 - lr: 0.0010
# Epoch 20/100
# 237/242 [============================>.] - ETA: 0s - loss: 0.5119 - auc: 0.5935
# Epoch 20: auc did not improve from 0.59496
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5119 - auc: 0.5938 - val_loss: 0.5129 - val_auc: 0.5510 - lr: 0.0010
# Epoch 21/100
# 238/242 [============================>.] - ETA: 0s - loss: 0.5117 - auc: 0.5918
# Epoch 21: auc did not improve from 0.59496
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5123 - auc: 0.5914 - val_loss: 0.5219 - val_auc: 0.5291 - lr: 0.0010
# Epoch 22/100
# 239/242 [============================>.] - ETA: 0s - loss: 0.5112 - auc: 0.5934
# Epoch 22: auc did not improve from 0.59496
# 242/242 [==============================] - 3s 12ms/step - loss: 0.5119 - auc: 0.5930 - val_loss: 0.5095 - val_auc: 0.5851 - lr: 0.0010
# Epoch 23/100
# 238/242 [============================>.] - ETA: 0s - loss: 0.5118 - auc: 0.5937
# Epoch 23: auc did not improve from 0.59496
# 242/242 [==============================] - 3s 11ms/step - loss: 0.5122 - auc: 0.5918 - val_loss: 0.5379 - val_auc: 0.5839 - lr: 0.0010
#
# fold_10
#
# Epoch 1/100
# 252/252 [==============================] - ETA: 0s - loss: 0.6046 - auc: 0.5363
# Epoch 1: auc did not improve from 0.59496
# 252/252 [==============================] - 5s 13ms/step - loss: 0.6046 - auc: 0.5363 - val_loss: 0.5310 - val_auc: 0.5678 - lr: 0.0010
# Epoch 2/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5235 - auc: 0.5689
# Epoch 2: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5235 - auc: 0.5689 - val_loss: 0.5174 - val_auc: 0.5717 - lr: 0.0010
# Epoch 3/100
# 246/252 [============================>.] - ETA: 0s - loss: 0.5157 - auc: 0.5735
# Epoch 3: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5152 - auc: 0.5749 - val_loss: 0.5157 - val_auc: 0.5830 - lr: 0.0010
# Epoch 4/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5130 - auc: 0.5821
# Epoch 4: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5130 - auc: 0.5821 - val_loss: 0.5161 - val_auc: 0.5646 - lr: 0.0010
# Epoch 5/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5120 - auc: 0.5832
# Epoch 5: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5120 - auc: 0.5827 - val_loss: 0.5128 - val_auc: 0.5848 - lr: 0.0010
# Epoch 6/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5117 - auc: 0.5862
# Epoch 6: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5115 - auc: 0.5856 - val_loss: 0.5122 - val_auc: 0.5869 - lr: 0.0010
# Epoch 7/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5118 - auc: 0.5851
# Epoch 7: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5115 - auc: 0.5851 - val_loss: 0.5132 - val_auc: 0.5844 - lr: 0.0010
# Epoch 8/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5112 - auc: 0.5867
# Epoch 8: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5109 - auc: 0.5862 - val_loss: 0.5095 - val_auc: 0.5907 - lr: 0.0010
# Epoch 9/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5111 - auc: 0.5872
# Epoch 9: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5109 - auc: 0.5865 - val_loss: 0.5088 - val_auc: 0.5885 - lr: 0.0010
# Epoch 10/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.5104 - auc: 0.5884
# Epoch 10: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5103 - auc: 0.5887 - val_loss: 0.5087 - val_auc: 0.5894 - lr: 0.0010
# Epoch 11/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5111 - auc: 0.5873
# Epoch 11: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5109 - auc: 0.5878 - val_loss: 0.5091 - val_auc: 0.5874 - lr: 0.0010
# Epoch 12/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5104 - auc: 0.5885
# Epoch 12: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5104 - auc: 0.5886 - val_loss: 0.5141 - val_auc: 0.5885 - lr: 0.0010
# Epoch 13/100
# 247/252 [============================>.] - ETA: 0s - loss: 0.5115 - auc: 0.5865
# Epoch 13: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5107 - auc: 0.5872 - val_loss: 0.5116 - val_auc: 0.5898 - lr: 0.0010
# Epoch 14/100
# 249/252 [============================>.] - ETA: 0s - loss: 0.5108 - auc: 0.5905
# Epoch 14: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5101 - auc: 0.5903 - val_loss: 0.5091 - val_auc: 0.5895 - lr: 0.0010
# Epoch 15/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5108 - auc: 0.5866
# Epoch 15: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5108 - auc: 0.5866 - val_loss: 0.5111 - val_auc: 0.5890 - lr: 0.0010
# Epoch 16/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5105 - auc: 0.5863
# Epoch 16: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5103 - auc: 0.5869 - val_loss: 0.5151 - val_auc: 0.5865 - lr: 0.0010
# Epoch 17/100
# 248/252 [============================>.] - ETA: 0s - loss: 0.5104 - auc: 0.5868
# Epoch 17: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5106 - auc: 0.5872 - val_loss: 0.5098 - val_auc: 0.5879 - lr: 0.0010
# Epoch 18/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5096 - auc: 0.5882
# Epoch 18: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5102 - auc: 0.5881 - val_loss: 0.5094 - val_auc: 0.5920 - lr: 0.0010
# Epoch 19/100
# 252/252 [==============================] - ETA: 0s - loss: 0.5104 - auc: 0.5876
# Epoch 19: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 11ms/step - loss: 0.5104 - auc: 0.5876 - val_loss: 0.5105 - val_auc: 0.5886 - lr: 0.0010
# Epoch 20/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.5104 - auc: 0.5881
# Epoch 20: auc did not improve from 0.59496
# 252/252 [==============================] - 3s 12ms/step - loss: 0.5104 - auc: 0.5884 - val_loss: 0.5093 - val_auc: 0.5901 - lr: 9.0000e-04

# %%
from google.colab import files
files.download('best.h5')
